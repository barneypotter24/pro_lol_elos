# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import pandas as pd
import numpy as np

# %%
class region():
    
    def __init__(self, name, default_rating):
        self.name = name
        self.default_rating = default_rating
        self.teams = []

class team():
    
    def __init__(self, name, region, initial_rating=None):
        
        self.name = name

        self.region = region
        if initial_rating:
            self.rating = initial_rating
        else:
            self.rating = region.default_rating
            
        self.game_dates = []
        self.rating_history = []
        
        region.teams.append(self)
            
        print("Added {} to as a team in {}. Their initial ELO is {}.".format(name, 
                                                                        region.name, self.rating))
def date_from_string(x):
    return datetime.datetime(*[int(item) for item in x.split('-')])


def game(winner, loser, date):
    
    date = date_from_string(date)
    
    print("Calculating Elo changes from {}'s victory over {} on {}.".format(winner.name, loser.name, date))
    winner.game_dates.append(date)
    loser.game_dates.append(date)
    
    nwr, nlr = calc_new_ratings(winner.rating, loser.rating)
    print("Game win increased {}'s Elo from {} to {}.".format(winner.name, winner.rating, nwr))
    winner.rating = nwr
    winner.rating_history.append(winner.rating)
    print("Game loss decreased {}'s Elo from {} to {}.".format(loser.name, loser.rating, nlr))
    loser.rating = nlr
    loser.rating_history.append(loser.rating)
    
def calc_new_ratings(r1, r2, k=32):
    '''
    docstring at some point
    '''
    # First, compute transformed ratings for each team
    R1 = 10 ** (r1/400)
    R2 = 10 ** (r2/400)
    
    # Second, comute expected score for each team
    E1 = R1/(R1+R2)
    E2 = R2/(R1+R2)
    
    # Third, set results
    S1 = 1
    S2 = 0
    
    # Fourth, update Elo ratings for each team
    new_r1 = round(r1 + k*(S1-E1))
    new_r2 = round(r2 + k*(S2-E2))
    
    return new_r1, new_r2

# %%
# Define teams and regions
## Define regions
EU = region('EU', 1500)
NA = region('NA', 1500)
KR = region('KR', 1600)
## Define teams for each region
### EU teams
FNC = team('Fnatic', EU)
G2 = team('G2 Esports', EU)
SPY = team('Splyce', EU)
VIT = team('Team Vitality', EU)
H2K = team('H2K', EU)
MSF = team('Misfits Gaming', EU)
ROC = team('ROCCAT', EU)
GIA = team('Giants', EU)
S04 = team('FC Schalke 04', EU)
UOL = team('Unicorns of Love', EU)

### NA teams
FOX = team('Echo Fox', NA)
C9 = team('Cloud9', NA)
T100 = team('100 Thieves', NA)
TSM = team('TSM', NA)
CG = team('Clutch Gaming', NA)
TL = team('Team Liquid', NA)
CLG = team('Counter Logic Gaming', NA)
FLY = team('FlyQuest', NA)
OPT = team('OpTic Gaming', NA)
GGS = team('Golden Guardians', NA)

### KR teams
KZ = team('KING-ZONE DragonX', KR)
AFS = team('Afreeca Freecs', KR)
KT = team('kt Rolster', KR)
KSV = team('KSV', KR)
ROX = team('ROX Tigers', KR)
MVP = team('MVP', KR)
JAG = team('Jin Air GreenWings', KR)
SKT = team('SK telecom T1', KR)
BBQ = team('bbq OLIVERS', KR)
KDM = team('KONGDOO MONSTER', KR)
# Out:
# Added Fnatic to as a team in EU. Their initial ELO is 1500.
# Added G2 Esports to as a team in EU. Their initial ELO is 1500.
# Added Splyce to as a team in EU. Their initial ELO is 1500.
# Added Team Vitality to as a team in EU. Their initial ELO is 1500.
# Added H2K to as a team in EU. Their initial ELO is 1500.
# Added Misfits Gaming to as a team in EU. Their initial ELO is 1500.
# Added ROCCAT to as a team in EU. Their initial ELO is 1500.
# Added Giants to as a team in EU. Their initial ELO is 1500.
# Added FC Schalke 04 to as a team in EU. Their initial ELO is 1500.
# Added Unicorns of Love to as a team in EU. Their initial ELO is 1500.
# Added Echo Fox to as a team in NA. Their initial ELO is 1500.
# Added Cloud9 to as a team in NA. Their initial ELO is 1500.
# Added 100 Thieves to as a team in NA. Their initial ELO is 1500.
# Added TSM to as a team in NA. Their initial ELO is 1500.
# Added Clutch Gaming to as a team in NA. Their initial ELO is 1500.
# Added Team Liquid to as a team in NA. Their initial ELO is 1500.
# Added Counter Logic Gaming to as a team in NA. Their initial ELO is 1500.
# Added FlyQuest to as a team in NA. Their initial ELO is 1500.
# Added OpTic Gaming to as a team in NA. Their initial ELO is 1500.
# Added Golden Guardians to as a team in NA. Their initial ELO is 1500.
# Added KING-ZONE DragonX to as a team in KR. Their initial ELO is 1600.
# Added Afreeca Freecs to as a team in KR. Their initial ELO is 1600.
# Added kt Rolster to as a team in KR. Their initial ELO is 1600.
# Added KSV to as a team in KR. Their initial ELO is 1600.
# Added ROX Tigers to as a team in KR. Their initial ELO is 1600.
# Added MVP to as a team in KR. Their initial ELO is 1600.
# Added Jin Air GreenWings to as a team in KR. Their initial ELO is 1600.
# Added SK telecom T1 to as a team in KR. Their initial ELO is 1600.
# Added bbq OLIVERS to as a team in KR. Their initial ELO is 1600.
# Added KONGDOO MONSTER to as a team in KR. Their initial ELO is 1600.

# %%
# Games
## EU LCS Spring Split 2018 #########################################
### Week 1
game(G2, MSF, '2018-01-19')
game(VIT, H2K, '2018-01-19')
game(GIA, UOL, '2018-01-19')
game(S04, ROC, '2018-01-19')
game(FNC, SPY, '2018-01-19')

game(VIT, GIA, '2018-01-20')
game(SPY, UOL, '2018-01-20')
game(H2K, FNC, '2018-01-20')
game(ROC, G2, '2018-01-20')
game(MSF, S04, '2018-01-20')

### Week 2
game(GIA, G2, '2018-01-26')
game(ROC, SPY, '2018-01-26')
game(MSF, H2K, '2018-01-26')
game(VIT, FNC, '2018-01-26')
game(S04, UOL, '2018-01-26')

game(GIA, H2K, '2018-01-27')
game(ROC, UOL, '2018-01-27')
game(MSF, VIT, '2018-01-27')
game(SPY, S04, '2018-01-27')
game(FNC, G2, '2018-01-27')

### Week 3
game(UOL, H2K, '2018-02-02')
game(GIA, ROC, '2018-02-02')
game(VIT, S04, '2018-02-02')
game(G2, SPY, '2018-02-02')
game(MSF, FNC, '2018-02-02')

game(VIT, UOL, '2018-02-03')
game(S04, GIA, '2018-02-03')
game(FNC, ROC, '2018-02-03')
game(G2, H2K, '2018-02-03')
game(SPY, MSF, '2018-02-03')

### Week 4
game(SPY, H2K, '2018-02-09')
game(VIT, ROC, '2018-02-09')
game(GIA, MSF, '2018-02-09')
game(FNC, UOL, '2018-02-09')
game(G2, S04, '2018-02-09')

game(VIT, SPY, '2018-02-10')
game(S04, H2K, '2018-02-10')
game(ROC, MSF, '2018-02-10')
game(FNC, GIA, '2018-02-10')
game(G2, UOL, '2018-02-10')

### Week 5
game(SPY, GIA, '2018-02-16')
game(H2K, ROC, '2018-02-16')
game(MSF, UOL, '2018-02-16')
game(G2, VIT, '2018-02-16')
game(FNC, S04, '2018-02-16')

game(UOL, GIA, '2018-02-17')
game(H2K, VIT, '2018-02-17')
game(ROC, S04, '2018-02-17')
game(G2, MSF, '2018-02-17')
game(FNC, SPY, '2018-02-17')

### Week 6
game(UOL, SPY, '2018-02-23')
game(G2, ROC, '2018-02-23')
game(FNC, H2K, '2018-02-23')
game(GIA, VIT, '2018-02-23')
game(S04, MSF, '2018-02-23')

game(UOL, ROC, '2018-02-24')
game(H2K, GIA, '2018-02-24')
game(SPY, S04, '2018-02-24')
game(FNC, G2, '2018-02-24')
game(MSF, VIT, '2018-02-24')

### Week 7
game(ROC, GIA, '2018-03-02')
game(UOL, H2K, '2018-03-02')
game(SPY, G2, '2018-03-02')
game(VIT, S04, '2018-03-02')
game(MSF, FNC, '2018-03-02')

game(SPY, ROC, '2018-03-03')
game(UOL, S04, '2018-03-03')
game(H2K, MSF, '2018-03-03')
game(FNC, VIT, '2018-03-03')
game(G2, GIA, '2018-03-03')

### Week 8
game(VIT, UOL, '2018-03-09')
game(S04, GIA, '2018-03-09')
game(SPY, MSF, '2018-03-09')
game(H2K, G2, '2018-03-09')
game(FNC, ROC, '2018-03-09')

game(GIA, MSF, '2018-03-10')
game(SPY, H2K, '2018-03-10')
game(ROC, VIT, '2018-03-10')
game(FNC, UOL, '2018-03-10')
game(S04, G2, '2018-03-10')

### Week 9
game(H2K, S04, '2018-03-16')
game(ROC, MSF, '2018-03-16')
game(VIT, SPY, '2018-03-16')
game(FNC, GIA, '2018-03-16')
game(G2, UOL, '2018-03-16')

game(SPY, GIA, '2018-03-17')
game(H2K, ROC, '2018-03-17')
game(MSF, UOL, '2018-03-17')
game(G2, VIT, '2018-03-17')
game(FNC, S04, '2018-03-17')

game(G2, SPY, '2018-03-17-12-00')

## NA LCS Spring Split 2018 ###################################
### Week 1
game(TL, TSM, '2018-01-20')
game(T100, OPT, '2018-01-20')
game(CG, GGS, '2018-01-20')
game(FOX, FLY, '2018-01-20')
game(C9, CLG, '2018-01-20')

game(TL, OPT, '2018-01-21')
game(FLY, TSM, '2018-01-21')
game(T100, CLG, '2018-01-21')
game(C9, GGS, '2018-01-21')
game(FOX, CG, '2018-01-21')

### Week 2
game(CG, CLG, '2018-01-27')
game(TSM, OPT, '2018-01-27')
game(FOX, C9, '2018-01-27')
game(T100, TL, '2018-01-27')
game(FLY, GGS, '2018-01-27')

game(FOX, TSM, '2018-01-28')
game(C9, T100, '2018-01-28')
game(OPT, FLY, '2018-01-28')
game(CLG, GGS, '2018-01-28')
game(TL, CG, '2018-01-28')

### Week 3
game(CLG, FOX, '2018-02-03')
game(C9, OPT, '2018-02-03')
game(T100, CG, '2018-02-03')
game(TL, FLY, '2018-02-03')
game(TSM, GGS, '2018-02-03')

game(FOX, OPT, '2018-02-04')
game(TSM, T100, '2018-02-04')
game(TL, GGS, '2018-02-04')
game(C9, CG, '2018-02-04')
game(CLG, FLY, '2018-02-04')

### Week 4
game(CG, TSM, '2018-02-10')
game(C9, TL, '2018-02-10')
game(OPT, CLG, '2018-02-10')
game(FLY, T100, '2018-02-10')
game(FOX, GGS, '2018-02-10')

game(C9, FLY, '2018-02-11')
game(GGS, T100, '2018-02-11')
game(TSM, CLG, '2018-02-11')
game(FOX, TL, '2018-02-11')
game(CG, OPT, '2018-02-11')

### Week 5
game(TL, CLG, '2018-02-17')
game(FOX, T100, '2018-02-17')
game(C9, TSM, '2018-02-17')
game(CG, FLY, '2018-02-17')
game(OPT, GGS, '2018-02-17')

game(CG, TSM, '2018-02-18')
game(GGS, TL, '2018-02-18')
game(FOX, C9, '2018-02-18')
game(T100, CLG, '2018-02-18')
game(FLY, OPT, '2018-02-18')

### Week 6
game(T100, C9, '2018-02-24')
game(CG, CLG, '2018-02-24')
game(TSM, FOX, '2018-02-24')
game(OPT, GGS, '2018-02-24')
game(TL, FLY, '2018-02-24')

game(TSM, OPT, '2018-02-25')
game(T100, FLY, '2018-02-25')
game(FOX, TL, '2018-02-25')
game(GGS, CLG, '2018-02-25')
game(C9, CG, '2018-02-25')

### Week 7
game(TL, T100, '2018-03-03')
game(TSM, FLY, '2018-03-03')
game(CLG, C9, '2018-03-03')
game(GGS, FOX, '2018-03-03')
game(CG, OPT, '2018-03-03')

game(CLG, TL, '2018-03-04')
game(FOX, OPT, '2018-03-04')
game(T100, TSM, '2018-03-04')
game(C9, GGS, '2018-03-04')
game(CG, FLY, '2018-03-04')

### Week 8
game(CG, FOX, '2018-03-10')
game(CLG, FLY, '2018-03-10')
game(C9, OPT, '2018-03-10')
game(TSM, TL, '2018-03-10')
game(T100, GGS, '2018-03-10')

game(CLG, FOX, '2018-03-11')
game(FLY, GGS, '2018-03-11')
game(TL, CG, '2018-03-11')
game(TSM, C9, '2018-03-11')
game(T100, OPT, '2018-03-11')

### Week 9
game(T100, CG, '2018-03-17')
game(FOX, FLY, '2018-03-17')
game(TL, C9, '2018-03-17')
game(TSM, GGS, '2018-03-17')
game(OPT, CLG, '2018-03-17')


## LCK Spring Split 2018 #########################################
### Week 1
game(KSV, KZ, '2018-01-16-00-00')
game(KSV, KZ, '2018-01-16-08-00')
game(KDM, MVP, '2018-01-16-00-00')
game(KDM, MVP, '2018-01-16-08-00')

game(AFS, KT, '2018-01-17-00-00')
game(KT, AFS, '2018-01-17-08-00')
game(AFS, KT, '2018-01-17-16-00')
game(SKT, ROX, '2018-01-17-00-00')
game(ROX, SKT, '2018-01-17-08-00')
game(SKT, ROX, '2018-01-17-16-00')

game(BBQ, KDM, '2018-01-18-00-00')
game(KDM, BBQ, '2018-01-18-08-00')
game(BBQ, KDM, '2018-01-18-16-00')
game(KSV, JAG, '2018-01-18-00-00')
game(KSV, JAG, '2018-01-18-08-00')

game(KT, MVP, '2018-01-20-00-00')
game(KT, MVP, '2018-01-20-08-00')
game(JAG, SKT, '2018-01-20-00-00')
game(SKT, JAG, '2018-01-20-08-00')
game(JAG, SKT, '2018-01-20-16-00')

## Week 2
game(KZ, AFS, '2018-01-23-00-00')
game(KZ, AFS, '2018-01-23-08-00')
game(ROX, BBQ, '2018-01-23-00-00')
game(BBQ, ROX, '2018-01-23-08-00')
game(ROX, BBQ, '2018-01-23-16-00')

game(JAG, MVP, '2018-01-24-00-00')
game(JAG, MVP, '2018-01-24-08-00')
game(KT, SKT, '2018-01-24-00-00')
game(SKT, KT, '2018-01-24-08-00')
game(KT, SKT, '2018-01-24-16-00')

game(ROX, KDM, '2018-01-25-00-00')
game(KDM, ROX, '2018-01-25-08-00')
game(ROX, KDM, '2018-01-25-16-00')
game(KSV, AFS, '2018-01-25-00-00')
game(AFS, KSV, '2018-01-25-08-00')
game(KSV, AFS, '2018-01-25-16-00')

game(KZ, SKT, '2018-01-26-00-00')
game(KZ, SKT, '2018-01-26-08-00')
game(KT, BBQ, '2018-01-26-00-00')
game(BBQ, KT, '2018-01-26-08-00')
game(KT, BBQ, '2018-01-26-16-00')

game(KDM, KSV, '2018-01-27-00-00')
game(KDM, KSV, '2018-01-27-08-00')
game(AFS, ROX, '2018-01-27-00-00')
game(AFS, ROX, '2018-01-27-08-00')

game(BBQ, JAG, '2018-01-28-00-00')
game(BBQ, JAG, '2018-01-28-08-00')
game(KZ, MVP, '2018-01-28-00-00')
game(KZ, MVP, '2018-01-28-08-00')

### Week 3
game(KSV, MVP, '2018-01-30-00-00')
game(KSV, MVP, '2018-01-30-08-00')
game(JAG, KDM, '2018-01-30-00-00')
game(JAG, KDM, '2018-01-30-08-00')

game(KZ, ROX, '2018-01-31-00-00')
game(KZ, ROX, '2018-01-31-08-00')
game(AFS, BBQ, '2018-01-31-00-00')
game(AFS, BBQ, '2018-01-31-08-00')

game(KT, JAG, '2018-02-01-00-00')
game(KT, JAG, '2018-02-01-08-00')
game(MVP, SKT, '2018-02-01-00-00')
game(SKT, MVP, '2018-02-01-08-00')
game(MVP, SKT, '2018-02-01-16-00')

game(KZ, KDM, '2018-02-03-00-00')
game(KZ, KDM, '2018-02-03-08-00')
game(KSV, BBQ, '2018-02-03-00-00')
game(BBQ, KSV, '2018-02-03-08-00')
game(KSV, BBQ, '2018-02-03-16-00')

game(KT, ROX, '2018-02-04-00-00')
game(ROX, KT, '2018-02-04-08-00')
game(KT, ROX, '2018-02-04-16-00')
game(AFS, SKT, '2018-02-04-00-00')
game(AFS, SKT, '2018-02-04-08-00')

### Week 4
game(ROX, KSV, '2018-02-06-00-00')
game(KSV, ROX, '2018-02-06-08-00')
game(ROX, KSV, '2018-02-06-16-00')
game(AFS, KDM, '2018-02-06-00-00')
game(AFS, KDM, '2018-02-06-08-00')

game(SKT, BBQ, '2018-02-07-00-00')
game(BBQ, SKT, '2018-02-07-08-00')
game(SKT, BBQ, '2018-02-07-16-00')
game(KZ, KT, '2018-02-07-00-00')
game(KZ, KT, '2018-02-07-08-00')

game(AFS, MVP, '2018-02-08-00-00')
game(AFS, MVP, '2018-02-08-08-00')
game(ROX, JAG, '2018-02-08-00-00')
game(JAG, ROX, '2018-02-08-08-00')
game(ROX, JAG, '2018-02-08-16-00')

game(KZ, JAG, '2018-02-10-00-00')
game(KZ, JAG, '2018-02-10-08-00')
game(MVP, BBQ, '2018-02-10-00-00')
game(MVP, BBQ, '2018-02-10-08-00')

game(SKT, KSV, '2018-02-11-00-00')
game(SKT, KSV, '2018-02-11-08-00')
game(KT, KDM, '2018-02-11-00-00')
game(KT, KDM, '2018-02-11-08-00')

### Week 5
game(SKT, KSV, '2018-02-20-00-00')
game(KDM, SKT, '2018-02-20-08-00')
game(SKT, KSV, '2018-02-20-16-00')
game(KT, KSV, '2018-02-20-00-00')
game(KT, KSV, '2018-02-20-08-00')

game(JAG, AFS, '2018-02-21-00-00')
game(JAG, AFS, '2018-02-21-08-00')
game(ROX, MVP, '2018-02-21-00-00')
game(ROX, MVP, '2018-02-21-08-00')

game(BBQ, KZ, '2018-02-22-00-00')
game(KZ, BBQ, '2018-02-22-08-00')
game(BBQ, KZ, '2018-02-22-16-00')
game(KSV, KDM, '2018-02-22-00-00')
game(KSV, KDM, '2018-02-22-08-00')

game(SKT, ROX, '2018-02-24-00-00')
game(SKT, ROX, '2018-02-24-08-00')
game(KZ, AFS, '2018-02-24-00-00')
game(AFS, KZ, '2018-02-24-08-00')
game(KZ, AFS, '2018-02-24-16-00')

game(KT, JAG, '2018-02-25-00-00')
game(JAG, KT, '2018-02-25-08-00')
game(KT, JAG, '2018-02-25-16-00')
game(MVP, BBQ, '2018-02-25-00-00')
game(MVP, BBQ, '2018-02-25-08-00')

### Week 6
game(AFS, KSV, '2018-02-27-00-00')
game(AFS, KSV, '2018-02-27-08-00')
game(ROX, KT, '2018-02-27-00-00')
game(ROX, KT, '2018-02-27-08-00')

game(BBQ, JAG, '2018-02-28-00-00')
game(BBQ, JAG, '2018-02-28-08-00')
game(KZ, MVP, '2018-02-28-00-00')
game(KZ, MVP, '2018-02-28-08-00')

game(AFS, SKT, '2018-03-01-00-00')
game(SKT, AFS, '2018-03-01-08-00')
game(AFS, SKT, '2018-03-01-16-00')
game(KT, KDM, '2018-03-01-00-00')
game(KT, KDM, '2018-03-01-08-00')

game(KZ, KDM, '2018-03-03-00-00')
game(KZ, KDM, '2018-03-03-08-00')
game(ROX, BBQ, '2018-03-03-00-00')
game(ROX, BBQ, '2018-03-03-08-00')

game(SKT, JAG, '2018-03-04-00-00')
game(JAG, SKT, '2018-03-04-08-00')
game(SKT, JAG, '2018-03-04-16-00')
game(MVP, KSV, '2018-03-04-00-00')
game(KSV, MVP, '2018-03-04-08-00')
game(MVP, KSV, '2018-03-04-16-00')

### Week 7
game(KZ, SKT, '2018-03-06-00-00')
game(KZ, SKT, '2018-03-06-08-00')
game(MVP, ROX, '2018-03-06-00-00')
game(MVP, ROX, '2018-03-06-08-00')

game(JAG, KDM, '2018-03-07-00-00')
game(JAG, KDM, '2018-03-07-08-00')
game(KSV, BBQ, '2018-03-07-00-00')
game(KSV, BBQ, '2018-03-07-08-00')

game(KT, SKT, '2018-03-08-00-00')
game(KT, SKT, '2018-03-08-08-00')
game(AFS, ROX, '2018-03-08-00-00')
game(AFS, ROX, '2018-03-08-08-00')

game(JAG, MVP, '2018-03-10-00-00')
game(MVP, JAG, '2018-03-10-08-00')
game(JAG, MVP, '2018-03-10-16-00')
game(KSV, KT, '2018-03-10-00-00')
game(KT, KSV, '2018-03-10-08-00')
game(KSV, KT, '2018-03-10-16-00')

game(AFS, KDM, '2018-03-11-00-00')
game(AFS, KDM, '2018-03-11-08-00')
game(KZ, BBQ, '2018-03-11-00-00')
game(KZ, BBQ, '2018-03-11-08-00')

### Week 8
game(KZ, ROX, '2018-03-13-00-00')
game(ROX, KZ, '2018-03-13-08-00')
game(KZ, ROX, '2018-03-13-16-00')
game(KSV, JAG, '2018-03-13-00-00')
game(JAG, KSV, '2018-03-13-08-00')
game(KSV, JAG, '2018-03-13-16-00')

game(MVP, KDM, '2018-03-14-00-00')
game(KDM, MVP, '2018-03-14-08-00')
game(MVP, KDM, '2018-03-14-16-00')
game(BBQ, SKT, '2018-03-14-00-00')
game(SKT, BBQ, '2018-03-14-08-00')
game(BBQ, SKT, '2018-03-14-16-00')

game(AFS, JAG, '2018-03-15-00-00')
game(JAG, AFS, '2018-03-15-08-00')
game(AFS, JAG, '2018-03-15-16-00')
game(KZ, KT, '2018-03-15-00-00')
game(KZ, KT, '2018-03-15-08-00')

game(AFS, MVP, '2018-03-17-00-00')
game(AFS, MVP, '2018-03-17-08-00')
game(KT, BBQ, '2018-03-17-00-00')
game(BBQ, KT, '2018-03-17-08-00')
game(KT, BBQ, '2018-03-17-16-00')
# Out:
# Calculating Elo changes from G2 Esports's victory over Misfits Gaming on 2018-01-19 00:00:00.
# Game win increased G2 Esports's Elo from 1500 to 1516.
# Game loss decreased Misfits Gaming's Elo from 1500 to 1484.
# Calculating Elo changes from Team Vitality's victory over H2K on 2018-01-19 00:00:00.
# Game win increased Team Vitality's Elo from 1500 to 1516.
# Game loss decreased H2K's Elo from 1500 to 1484.
# Calculating Elo changes from Giants's victory over Unicorns of Love on 2018-01-19 00:00:00.
# Game win increased Giants's Elo from 1500 to 1516.
# Game loss decreased Unicorns of Love's Elo from 1500 to 1484.
# Calculating Elo changes from FC Schalke 04's victory over ROCCAT on 2018-01-19 00:00:00.
# Game win increased FC Schalke 04's Elo from 1500 to 1516.
# Game loss decreased ROCCAT's Elo from 1500 to 1484.
# Calculating Elo changes from Fnatic's victory over Splyce on 2018-01-19 00:00:00.
# Game win increased Fnatic's Elo from 1500 to 1516.
# Game loss decreased Splyce's Elo from 1500 to 1484.
# Calculating Elo changes from Team Vitality's victory over Giants on 2018-01-20 00:00:00.
# Game win increased Team Vitality's Elo from 1516 to 1532.
# Game loss decreased Giants's Elo from 1516 to 1500.
# Calculating Elo changes from Splyce's victory over Unicorns of Love on 2018-01-20 00:00:00.
# Game win increased Splyce's Elo from 1484 to 1500.
# Game loss decreased Unicorns of Love's Elo from 1484 to 1468.
# Calculating Elo changes from H2K's victory over Fnatic on 2018-01-20 00:00:00.
# Game win increased H2K's Elo from 1484 to 1501.
# Game loss decreased Fnatic's Elo from 1516 to 1499.
# Calculating Elo changes from ROCCAT's victory over G2 Esports on 2018-01-20 00:00:00.
# Game win increased ROCCAT's Elo from 1484 to 1501.
# Game loss decreased G2 Esports's Elo from 1516 to 1499.
# Calculating Elo changes from Misfits Gaming's victory over FC Schalke 04 on 2018-01-20 00:00:00.
# Game win increased Misfits Gaming's Elo from 1484 to 1501.
# Game loss decreased FC Schalke 04's Elo from 1516 to 1499.
# Calculating Elo changes from Giants's victory over G2 Esports on 2018-01-26 00:00:00.
# Game win increased Giants's Elo from 1500 to 1516.
# Game loss decreased G2 Esports's Elo from 1499 to 1483.
# Calculating Elo changes from ROCCAT's victory over Splyce on 2018-01-26 00:00:00.
# Game win increased ROCCAT's Elo from 1501 to 1517.
# Game loss decreased Splyce's Elo from 1500 to 1484.
# Calculating Elo changes from Misfits Gaming's victory over H2K on 2018-01-26 00:00:00.
# Game win increased Misfits Gaming's Elo from 1501 to 1517.
# Game loss decreased H2K's Elo from 1501 to 1485.
# Calculating Elo changes from Team Vitality's victory over Fnatic on 2018-01-26 00:00:00.
# Game win increased Team Vitality's Elo from 1532 to 1546.
# Game loss decreased Fnatic's Elo from 1499 to 1485.
# Calculating Elo changes from FC Schalke 04's victory over Unicorns of Love on 2018-01-26 00:00:00.
# Game win increased FC Schalke 04's Elo from 1499 to 1514.
# Game loss decreased Unicorns of Love's Elo from 1468 to 1453.
# Calculating Elo changes from Giants's victory over H2K on 2018-01-27 00:00:00.
# Game win increased Giants's Elo from 1516 to 1531.
# Game loss decreased H2K's Elo from 1485 to 1470.
# Calculating Elo changes from ROCCAT's victory over Unicorns of Love on 2018-01-27 00:00:00.
# Game win increased ROCCAT's Elo from 1517 to 1530.
# Game loss decreased Unicorns of Love's Elo from 1453 to 1440.
# Calculating Elo changes from Misfits Gaming's victory over Team Vitality on 2018-01-27 00:00:00.
# Game win increased Misfits Gaming's Elo from 1517 to 1534.
# Game loss decreased Team Vitality's Elo from 1546 to 1529.
# Calculating Elo changes from Splyce's victory over FC Schalke 04 on 2018-01-27 00:00:00.
# Game win increased Splyce's Elo from 1484 to 1501.
# Game loss decreased FC Schalke 04's Elo from 1514 to 1497.
# Calculating Elo changes from Fnatic's victory over G2 Esports on 2018-01-27 00:00:00.
# Game win increased Fnatic's Elo from 1485 to 1501.
# Game loss decreased G2 Esports's Elo from 1483 to 1467.
# Calculating Elo changes from Unicorns of Love's victory over H2K on 2018-02-02 00:00:00.
# Game win increased Unicorns of Love's Elo from 1440 to 1457.
# Game loss decreased H2K's Elo from 1470 to 1453.
# Calculating Elo changes from Giants's victory over ROCCAT on 2018-02-02 00:00:00.
# Game win increased Giants's Elo from 1531 to 1547.
# Game loss decreased ROCCAT's Elo from 1530 to 1514.
# Calculating Elo changes from Team Vitality's victory over FC Schalke 04 on 2018-02-02 00:00:00.
# Game win increased Team Vitality's Elo from 1529 to 1544.
# Game loss decreased FC Schalke 04's Elo from 1497 to 1482.
# Calculating Elo changes from G2 Esports's victory over Splyce on 2018-02-02 00:00:00.
# Game win increased G2 Esports's Elo from 1467 to 1485.
# Game loss decreased Splyce's Elo from 1501 to 1483.
# Calculating Elo changes from Misfits Gaming's victory over Fnatic on 2018-02-02 00:00:00.
# Game win increased Misfits Gaming's Elo from 1534 to 1548.
# Game loss decreased Fnatic's Elo from 1501 to 1487.
# Calculating Elo changes from Team Vitality's victory over Unicorns of Love on 2018-02-03 00:00:00.
# Game win increased Team Vitality's Elo from 1544 to 1556.
# Game loss decreased Unicorns of Love's Elo from 1457 to 1445.
# Calculating Elo changes from FC Schalke 04's victory over Giants on 2018-02-03 00:00:00.
# Game win increased FC Schalke 04's Elo from 1482 to 1501.
# Game loss decreased Giants's Elo from 1547 to 1528.
# Calculating Elo changes from Fnatic's victory over ROCCAT on 2018-02-03 00:00:00.
# Game win increased Fnatic's Elo from 1487 to 1504.
# Game loss decreased ROCCAT's Elo from 1514 to 1497.
# Calculating Elo changes from G2 Esports's victory over H2K on 2018-02-03 00:00:00.
# Game win increased G2 Esports's Elo from 1485 to 1500.
# Game loss decreased H2K's Elo from 1453 to 1438.
# Calculating Elo changes from Splyce's victory over Misfits Gaming on 2018-02-03 00:00:00.
# Game win increased Splyce's Elo from 1483 to 1502.
# Game loss decreased Misfits Gaming's Elo from 1548 to 1529.
# Calculating Elo changes from Splyce's victory over H2K on 2018-02-09 00:00:00.
# Game win increased Splyce's Elo from 1502 to 1515.
# Game loss decreased H2K's Elo from 1438 to 1425.
# Calculating Elo changes from Team Vitality's victory over ROCCAT on 2018-02-09 00:00:00.
# Game win increased Team Vitality's Elo from 1556 to 1569.
# Game loss decreased ROCCAT's Elo from 1497 to 1484.
# Calculating Elo changes from Giants's victory over Misfits Gaming on 2018-02-09 00:00:00.
# Game win increased Giants's Elo from 1528 to 1544.
# Game loss decreased Misfits Gaming's Elo from 1529 to 1513.
# Calculating Elo changes from Fnatic's victory over Unicorns of Love on 2018-02-09 00:00:00.
# Game win increased Fnatic's Elo from 1504 to 1517.
# Game loss decreased Unicorns of Love's Elo from 1445 to 1432.
# Calculating Elo changes from G2 Esports's victory over FC Schalke 04 on 2018-02-09 00:00:00.
# Game win increased G2 Esports's Elo from 1500 to 1516.
# Game loss decreased FC Schalke 04's Elo from 1501 to 1485.
# Calculating Elo changes from Team Vitality's victory over Splyce on 2018-02-10 00:00:00.
# Game win increased Team Vitality's Elo from 1569 to 1583.
# Game loss decreased Splyce's Elo from 1515 to 1501.
# Calculating Elo changes from FC Schalke 04's victory over H2K on 2018-02-10 00:00:00.
# Game win increased FC Schalke 04's Elo from 1485 to 1498.
# Game loss decreased H2K's Elo from 1425 to 1412.
# Calculating Elo changes from ROCCAT's victory over Misfits Gaming on 2018-02-10 00:00:00.
# Game win increased ROCCAT's Elo from 1484 to 1501.
# Game loss decreased Misfits Gaming's Elo from 1513 to 1496.
# Calculating Elo changes from Fnatic's victory over Giants on 2018-02-10 00:00:00.
# Game win increased Fnatic's Elo from 1517 to 1534.
# Game loss decreased Giants's Elo from 1544 to 1527.
# Calculating Elo changes from G2 Esports's victory over Unicorns of Love on 2018-02-10 00:00:00.
# Game win increased G2 Esports's Elo from 1516 to 1528.
# Game loss decreased Unicorns of Love's Elo from 1432 to 1420.
# Calculating Elo changes from Splyce's victory over Giants on 2018-02-16 00:00:00.
# Game win increased Splyce's Elo from 1501 to 1518.
# Game loss decreased Giants's Elo from 1527 to 1510.
# Calculating Elo changes from H2K's victory over ROCCAT on 2018-02-16 00:00:00.
# Game win increased H2K's Elo from 1412 to 1432.
# Game loss decreased ROCCAT's Elo from 1501 to 1481.
# Calculating Elo changes from Misfits Gaming's victory over Unicorns of Love on 2018-02-16 00:00:00.
# Game win increased Misfits Gaming's Elo from 1496 to 1509.
# Game loss decreased Unicorns of Love's Elo from 1420 to 1407.
# Calculating Elo changes from G2 Esports's victory over Team Vitality on 2018-02-16 00:00:00.
# Game win increased G2 Esports's Elo from 1528 to 1547.
# Game loss decreased Team Vitality's Elo from 1583 to 1564.
# Calculating Elo changes from Fnatic's victory over FC Schalke 04 on 2018-02-16 00:00:00.
# Game win increased Fnatic's Elo from 1534 to 1548.
# Game loss decreased FC Schalke 04's Elo from 1498 to 1484.
# Calculating Elo changes from Unicorns of Love's victory over Giants on 2018-02-17 00:00:00.
# Game win increased Unicorns of Love's Elo from 1407 to 1428.
# Game loss decreased Giants's Elo from 1510 to 1489.
# Calculating Elo changes from H2K's victory over Team Vitality on 2018-02-17 00:00:00.
# Game win increased H2K's Elo from 1432 to 1454.
# Game loss decreased Team Vitality's Elo from 1564 to 1542.
# Calculating Elo changes from ROCCAT's victory over FC Schalke 04 on 2018-02-17 00:00:00.
# Game win increased ROCCAT's Elo from 1481 to 1497.
# Game loss decreased FC Schalke 04's Elo from 1484 to 1468.
# Calculating Elo changes from G2 Esports's victory over Misfits Gaming on 2018-02-17 00:00:00.
# Game win increased G2 Esports's Elo from 1547 to 1561.
# Game loss decreased Misfits Gaming's Elo from 1509 to 1495.
# Calculating Elo changes from Fnatic's victory over Splyce on 2018-02-17 00:00:00.
# Game win increased Fnatic's Elo from 1548 to 1563.
# Game loss decreased Splyce's Elo from 1518 to 1503.
# Calculating Elo changes from Unicorns of Love's victory over Splyce on 2018-02-23 00:00:00.
# Game win increased Unicorns of Love's Elo from 1428 to 1447.
# Game loss decreased Splyce's Elo from 1503 to 1484.
# Calculating Elo changes from G2 Esports's victory over ROCCAT on 2018-02-23 00:00:00.
# Game win increased G2 Esports's Elo from 1561 to 1574.
# Game loss decreased ROCCAT's Elo from 1497 to 1484.
# Calculating Elo changes from Fnatic's victory over H2K on 2018-02-23 00:00:00.
# Game win increased Fnatic's Elo from 1563 to 1574.
# Game loss decreased H2K's Elo from 1454 to 1443.
# Calculating Elo changes from Giants's victory over Team Vitality on 2018-02-23 00:00:00.
# Game win increased Giants's Elo from 1489 to 1507.
# Game loss decreased Team Vitality's Elo from 1542 to 1524.
# Calculating Elo changes from FC Schalke 04's victory over Misfits Gaming on 2018-02-23 00:00:00.
# Game win increased FC Schalke 04's Elo from 1468 to 1485.
# Game loss decreased Misfits Gaming's Elo from 1495 to 1478.
# Calculating Elo changes from Unicorns of Love's victory over ROCCAT on 2018-02-24 00:00:00.
# Game win increased Unicorns of Love's Elo from 1447 to 1465.
# Game loss decreased ROCCAT's Elo from 1484 to 1466.
# Calculating Elo changes from H2K's victory over Giants on 2018-02-24 00:00:00.
# Game win increased H2K's Elo from 1443 to 1462.
# Game loss decreased Giants's Elo from 1507 to 1488.
# Calculating Elo changes from Splyce's victory over FC Schalke 04 on 2018-02-24 00:00:00.
# Game win increased Splyce's Elo from 1484 to 1500.
# Game loss decreased FC Schalke 04's Elo from 1485 to 1469.
# Calculating Elo changes from Fnatic's victory over G2 Esports on 2018-02-24 00:00:00.
# Game win increased Fnatic's Elo from 1574 to 1590.
# Game loss decreased G2 Esports's Elo from 1574 to 1558.
# Calculating Elo changes from Misfits Gaming's victory over Team Vitality on 2018-02-24 00:00:00.
# Game win increased Misfits Gaming's Elo from 1478 to 1496.
# Game loss decreased Team Vitality's Elo from 1524 to 1506.
# Calculating Elo changes from ROCCAT's victory over Giants on 2018-03-02 00:00:00.
# Game win increased ROCCAT's Elo from 1466 to 1483.
# Game loss decreased Giants's Elo from 1488 to 1471.
# Calculating Elo changes from Unicorns of Love's victory over H2K on 2018-03-02 00:00:00.
# Game win increased Unicorns of Love's Elo from 1465 to 1481.
# Game loss decreased H2K's Elo from 1462 to 1446.
# Calculating Elo changes from Splyce's victory over G2 Esports on 2018-03-02 00:00:00.
# Game win increased Splyce's Elo from 1500 to 1519.
# Game loss decreased G2 Esports's Elo from 1558 to 1539.
# Calculating Elo changes from Team Vitality's victory over FC Schalke 04 on 2018-03-02 00:00:00.
# Game win increased Team Vitality's Elo from 1506 to 1520.
# Game loss decreased FC Schalke 04's Elo from 1469 to 1455.
# Calculating Elo changes from Misfits Gaming's victory over Fnatic on 2018-03-02 00:00:00.
# Game win increased Misfits Gaming's Elo from 1496 to 1516.
# Game loss decreased Fnatic's Elo from 1590 to 1570.
# Calculating Elo changes from Splyce's victory over ROCCAT on 2018-03-03 00:00:00.
# Game win increased Splyce's Elo from 1519 to 1533.
# Game loss decreased ROCCAT's Elo from 1483 to 1469.
# Calculating Elo changes from Unicorns of Love's victory over FC Schalke 04 on 2018-03-03 00:00:00.
# Game win increased Unicorns of Love's Elo from 1481 to 1496.
# Game loss decreased FC Schalke 04's Elo from 1455 to 1440.
# Calculating Elo changes from H2K's victory over Misfits Gaming on 2018-03-03 00:00:00.
# Game win increased H2K's Elo from 1446 to 1465.
# Game loss decreased Misfits Gaming's Elo from 1516 to 1497.
# Calculating Elo changes from Fnatic's victory over Team Vitality on 2018-03-03 00:00:00.
# Game win increased Fnatic's Elo from 1570 to 1584.
# Game loss decreased Team Vitality's Elo from 1520 to 1506.
# Calculating Elo changes from G2 Esports's victory over Giants on 2018-03-03 00:00:00.
# Game win increased G2 Esports's Elo from 1539 to 1552.
# Game loss decreased Giants's Elo from 1471 to 1458.
# Calculating Elo changes from Team Vitality's victory over Unicorns of Love on 2018-03-09 00:00:00.
# Game win increased Team Vitality's Elo from 1506 to 1522.
# Game loss decreased Unicorns of Love's Elo from 1496 to 1480.
# Calculating Elo changes from FC Schalke 04's victory over Giants on 2018-03-09 00:00:00.
# Game win increased FC Schalke 04's Elo from 1440 to 1457.
# Game loss decreased Giants's Elo from 1458 to 1441.
# Calculating Elo changes from Splyce's victory over Misfits Gaming on 2018-03-09 00:00:00.
# Game win increased Splyce's Elo from 1533 to 1547.
# Game loss decreased Misfits Gaming's Elo from 1497 to 1483.
# Calculating Elo changes from H2K's victory over G2 Esports on 2018-03-09 00:00:00.
# Game win increased H2K's Elo from 1465 to 1485.
# Game loss decreased G2 Esports's Elo from 1552 to 1532.
# Calculating Elo changes from Fnatic's victory over ROCCAT on 2018-03-09 00:00:00.
# Game win increased Fnatic's Elo from 1584 to 1595.
# Game loss decreased ROCCAT's Elo from 1469 to 1458.
# Calculating Elo changes from Giants's victory over Misfits Gaming on 2018-03-10 00:00:00.
# Game win increased Giants's Elo from 1441 to 1459.
# Game loss decreased Misfits Gaming's Elo from 1483 to 1465.
# Calculating Elo changes from Splyce's victory over H2K on 2018-03-10 00:00:00.
# Game win increased Splyce's Elo from 1547 to 1560.
# Game loss decreased H2K's Elo from 1485 to 1472.
# Calculating Elo changes from ROCCAT's victory over Team Vitality on 2018-03-10 00:00:00.
# Game win increased ROCCAT's Elo from 1458 to 1477.
# Game loss decreased Team Vitality's Elo from 1522 to 1503.
# Calculating Elo changes from Fnatic's victory over Unicorns of Love on 2018-03-10 00:00:00.
# Game win increased Fnatic's Elo from 1595 to 1606.
# Game loss decreased Unicorns of Love's Elo from 1480 to 1469.
# Calculating Elo changes from FC Schalke 04's victory over G2 Esports on 2018-03-10 00:00:00.
# Game win increased FC Schalke 04's Elo from 1457 to 1476.
# Game loss decreased G2 Esports's Elo from 1532 to 1513.
# Calculating Elo changes from H2K's victory over FC Schalke 04 on 2018-03-16 00:00:00.
# Game win increased H2K's Elo from 1472 to 1488.
# Game loss decreased FC Schalke 04's Elo from 1476 to 1460.
# Calculating Elo changes from ROCCAT's victory over Misfits Gaming on 2018-03-16 00:00:00.
# Game win increased ROCCAT's Elo from 1477 to 1492.
# Game loss decreased Misfits Gaming's Elo from 1465 to 1450.
# Calculating Elo changes from Team Vitality's victory over Splyce on 2018-03-16 00:00:00.
# Game win increased Team Vitality's Elo from 1503 to 1522.
# Game loss decreased Splyce's Elo from 1560 to 1541.
# Calculating Elo changes from Fnatic's victory over Giants on 2018-03-16 00:00:00.
# Game win increased Fnatic's Elo from 1606 to 1616.
# Game loss decreased Giants's Elo from 1459 to 1449.
# Calculating Elo changes from G2 Esports's victory over Unicorns of Love on 2018-03-16 00:00:00.
# Game win increased G2 Esports's Elo from 1513 to 1527.
# Game loss decreased Unicorns of Love's Elo from 1469 to 1455.
# Calculating Elo changes from Splyce's victory over Giants on 2018-03-17 00:00:00.
# Game win increased Splyce's Elo from 1541 to 1553.
# Game loss decreased Giants's Elo from 1449 to 1437.
# Calculating Elo changes from H2K's victory over ROCCAT on 2018-03-17 00:00:00.
# Game win increased H2K's Elo from 1488 to 1504.
# Game loss decreased ROCCAT's Elo from 1492 to 1476.
# Calculating Elo changes from Misfits Gaming's victory over Unicorns of Love on 2018-03-17 00:00:00.
# Game win increased Misfits Gaming's Elo from 1450 to 1466.
# Game loss decreased Unicorns of Love's Elo from 1455 to 1439.
# Calculating Elo changes from G2 Esports's victory over Team Vitality on 2018-03-17 00:00:00.
# Game win increased G2 Esports's Elo from 1527 to 1543.
# Game loss decreased Team Vitality's Elo from 1522 to 1506.
# Calculating Elo changes from Fnatic's victory over FC Schalke 04 on 2018-03-17 00:00:00.
# Game win increased Fnatic's Elo from 1616 to 1625.
# Game loss decreased FC Schalke 04's Elo from 1460 to 1451.
# Calculating Elo changes from G2 Esports's victory over Splyce on 2018-03-17 12:00:00.
# Game win increased G2 Esports's Elo from 1543 to 1559.
# Game loss decreased Splyce's Elo from 1553 to 1537.
# Calculating Elo changes from Team Liquid's victory over TSM on 2018-01-20 00:00:00.
# Game win increased Team Liquid's Elo from 1500 to 1516.
# Game loss decreased TSM's Elo from 1500 to 1484.
# Calculating Elo changes from 100 Thieves's victory over OpTic Gaming on 2018-01-20 00:00:00.
# Game win increased 100 Thieves's Elo from 1500 to 1516.
# Game loss decreased OpTic Gaming's Elo from 1500 to 1484.
# Calculating Elo changes from Clutch Gaming's victory over Golden Guardians on 2018-01-20 00:00:00.
# Game win increased Clutch Gaming's Elo from 1500 to 1516.
# Game loss decreased Golden Guardians's Elo from 1500 to 1484.
# Calculating Elo changes from Echo Fox's victory over FlyQuest on 2018-01-20 00:00:00.
# Game win increased Echo Fox's Elo from 1500 to 1516.
# Game loss decreased FlyQuest's Elo from 1500 to 1484.
# Calculating Elo changes from Cloud9's victory over Counter Logic Gaming on 2018-01-20 00:00:00.
# Game win increased Cloud9's Elo from 1500 to 1516.
# Game loss decreased Counter Logic Gaming's Elo from 1500 to 1484.
# Calculating Elo changes from Team Liquid's victory over OpTic Gaming on 2018-01-21 00:00:00.
# Game win increased Team Liquid's Elo from 1516 to 1531.
# Game loss decreased OpTic Gaming's Elo from 1484 to 1469.
# Calculating Elo changes from FlyQuest's victory over TSM on 2018-01-21 00:00:00.
# Game win increased FlyQuest's Elo from 1484 to 1500.
# Game loss decreased TSM's Elo from 1484 to 1468.
# Calculating Elo changes from 100 Thieves's victory over Counter Logic Gaming on 2018-01-21 00:00:00.
# Game win increased 100 Thieves's Elo from 1516 to 1531.
# Game loss decreased Counter Logic Gaming's Elo from 1484 to 1469.
# Calculating Elo changes from Cloud9's victory over Golden Guardians on 2018-01-21 00:00:00.
# Game win increased Cloud9's Elo from 1516 to 1531.
# Game loss decreased Golden Guardians's Elo from 1484 to 1469.
# Calculating Elo changes from Echo Fox's victory over Clutch Gaming on 2018-01-21 00:00:00.
# Game win increased Echo Fox's Elo from 1516 to 1532.
# Game loss decreased Clutch Gaming's Elo from 1516 to 1500.
# Calculating Elo changes from Clutch Gaming's victory over Counter Logic Gaming on 2018-01-27 00:00:00.
# Game win increased Clutch Gaming's Elo from 1500 to 1515.
# Game loss decreased Counter Logic Gaming's Elo from 1469 to 1454.
# Calculating Elo changes from TSM's victory over OpTic Gaming on 2018-01-27 00:00:00.
# Game win increased TSM's Elo from 1468 to 1484.
# Game loss decreased OpTic Gaming's Elo from 1469 to 1453.
# Calculating Elo changes from Echo Fox's victory over Cloud9 on 2018-01-27 00:00:00.
# Game win increased Echo Fox's Elo from 1532 to 1548.
# Game loss decreased Cloud9's Elo from 1531 to 1515.
# Calculating Elo changes from 100 Thieves's victory over Team Liquid on 2018-01-27 00:00:00.
# Game win increased 100 Thieves's Elo from 1531 to 1547.
# Game loss decreased Team Liquid's Elo from 1531 to 1515.
# Calculating Elo changes from FlyQuest's victory over Golden Guardians on 2018-01-27 00:00:00.
# Game win increased FlyQuest's Elo from 1500 to 1515.
# Game loss decreased Golden Guardians's Elo from 1469 to 1454.
# Calculating Elo changes from Echo Fox's victory over TSM on 2018-01-28 00:00:00.
# Game win increased Echo Fox's Elo from 1548 to 1561.
# Game loss decreased TSM's Elo from 1484 to 1471.
# Calculating Elo changes from Cloud9's victory over 100 Thieves on 2018-01-28 00:00:00.
# Game win increased Cloud9's Elo from 1515 to 1532.
# Game loss decreased 100 Thieves's Elo from 1547 to 1530.
# Calculating Elo changes from OpTic Gaming's victory over FlyQuest on 2018-01-28 00:00:00.
# Game win increased OpTic Gaming's Elo from 1453 to 1472.
# Game loss decreased FlyQuest's Elo from 1515 to 1496.
# Calculating Elo changes from Counter Logic Gaming's victory over Golden Guardians on 2018-01-28 00:00:00.
# Game win increased Counter Logic Gaming's Elo from 1454 to 1470.
# Game loss decreased Golden Guardians's Elo from 1454 to 1438.
# Calculating Elo changes from Team Liquid's victory over Clutch Gaming on 2018-01-28 00:00:00.
# Game win increased Team Liquid's Elo from 1515 to 1531.
# Game loss decreased Clutch Gaming's Elo from 1515 to 1499.
# Calculating Elo changes from Counter Logic Gaming's victory over Echo Fox on 2018-02-03 00:00:00.
# Game win increased Counter Logic Gaming's Elo from 1470 to 1490.
# Game loss decreased Echo Fox's Elo from 1561 to 1541.
# Calculating Elo changes from Cloud9's victory over OpTic Gaming on 2018-02-03 00:00:00.
# Game win increased Cloud9's Elo from 1532 to 1545.
# Game loss decreased OpTic Gaming's Elo from 1472 to 1459.
# Calculating Elo changes from 100 Thieves's victory over Clutch Gaming on 2018-02-03 00:00:00.
# Game win increased 100 Thieves's Elo from 1530 to 1545.
# Game loss decreased Clutch Gaming's Elo from 1499 to 1484.
# Calculating Elo changes from Team Liquid's victory over FlyQuest on 2018-02-03 00:00:00.
# Game win increased Team Liquid's Elo from 1531 to 1545.
# Game loss decreased FlyQuest's Elo from 1496 to 1482.
# Calculating Elo changes from TSM's victory over Golden Guardians on 2018-02-03 00:00:00.
# Game win increased TSM's Elo from 1471 to 1485.
# Game loss decreased Golden Guardians's Elo from 1438 to 1424.
# Calculating Elo changes from Echo Fox's victory over OpTic Gaming on 2018-02-04 00:00:00.
# Game win increased Echo Fox's Elo from 1541 to 1553.
# Game loss decreased OpTic Gaming's Elo from 1459 to 1447.
# Calculating Elo changes from TSM's victory over 100 Thieves on 2018-02-04 00:00:00.
# Game win increased TSM's Elo from 1485 to 1504.
# Game loss decreased 100 Thieves's Elo from 1545 to 1526.
# Calculating Elo changes from Team Liquid's victory over Golden Guardians on 2018-02-04 00:00:00.
# Game win increased Team Liquid's Elo from 1545 to 1556.
# Game loss decreased Golden Guardians's Elo from 1424 to 1413.
# Calculating Elo changes from Cloud9's victory over Clutch Gaming on 2018-02-04 00:00:00.
# Game win increased Cloud9's Elo from 1545 to 1558.
# Game loss decreased Clutch Gaming's Elo from 1484 to 1471.
# Calculating Elo changes from Counter Logic Gaming's victory over FlyQuest on 2018-02-04 00:00:00.
# Game win increased Counter Logic Gaming's Elo from 1490 to 1506.
# Game loss decreased FlyQuest's Elo from 1482 to 1466.
# Calculating Elo changes from Clutch Gaming's victory over TSM on 2018-02-10 00:00:00.
# Game win increased Clutch Gaming's Elo from 1471 to 1489.
# Game loss decreased TSM's Elo from 1504 to 1486.
# Calculating Elo changes from Cloud9's victory over Team Liquid on 2018-02-10 00:00:00.
# Game win increased Cloud9's Elo from 1558 to 1574.
# Game loss decreased Team Liquid's Elo from 1556 to 1540.
# Calculating Elo changes from OpTic Gaming's victory over Counter Logic Gaming on 2018-02-10 00:00:00.
# Game win increased OpTic Gaming's Elo from 1447 to 1466.
# Game loss decreased Counter Logic Gaming's Elo from 1506 to 1487.
# Calculating Elo changes from FlyQuest's victory over 100 Thieves on 2018-02-10 00:00:00.
# Game win increased FlyQuest's Elo from 1466 to 1485.
# Game loss decreased 100 Thieves's Elo from 1526 to 1507.
# Calculating Elo changes from Echo Fox's victory over Golden Guardians on 2018-02-10 00:00:00.
# Game win increased Echo Fox's Elo from 1553 to 1563.
# Game loss decreased Golden Guardians's Elo from 1413 to 1403.
# Calculating Elo changes from Cloud9's victory over FlyQuest on 2018-02-11 00:00:00.
# Game win increased Cloud9's Elo from 1574 to 1586.
# Game loss decreased FlyQuest's Elo from 1485 to 1473.
# Calculating Elo changes from Golden Guardians's victory over 100 Thieves on 2018-02-11 00:00:00.
# Game win increased Golden Guardians's Elo from 1403 to 1424.
# Game loss decreased 100 Thieves's Elo from 1507 to 1486.
# Calculating Elo changes from TSM's victory over Counter Logic Gaming on 2018-02-11 00:00:00.
# Game win increased TSM's Elo from 1486 to 1502.
# Game loss decreased Counter Logic Gaming's Elo from 1487 to 1471.
# Calculating Elo changes from Echo Fox's victory over Team Liquid on 2018-02-11 00:00:00.
# Game win increased Echo Fox's Elo from 1563 to 1578.
# Game loss decreased Team Liquid's Elo from 1540 to 1525.
# Calculating Elo changes from Clutch Gaming's victory over OpTic Gaming on 2018-02-11 00:00:00.
# Game win increased Clutch Gaming's Elo from 1489 to 1504.
# Game loss decreased OpTic Gaming's Elo from 1466 to 1451.
# Calculating Elo changes from Team Liquid's victory over Counter Logic Gaming on 2018-02-17 00:00:00.
# Game win increased Team Liquid's Elo from 1525 to 1539.
# Game loss decreased Counter Logic Gaming's Elo from 1471 to 1457.
# Calculating Elo changes from Echo Fox's victory over 100 Thieves on 2018-02-17 00:00:00.
# Game win increased Echo Fox's Elo from 1578 to 1590.
# Game loss decreased 100 Thieves's Elo from 1486 to 1474.
# Calculating Elo changes from Cloud9's victory over TSM on 2018-02-17 00:00:00.
# Game win increased Cloud9's Elo from 1586 to 1598.
# Game loss decreased TSM's Elo from 1502 to 1490.
# Calculating Elo changes from Clutch Gaming's victory over FlyQuest on 2018-02-17 00:00:00.
# Game win increased Clutch Gaming's Elo from 1504 to 1519.
# Game loss decreased FlyQuest's Elo from 1473 to 1458.
# Calculating Elo changes from OpTic Gaming's victory over Golden Guardians on 2018-02-17 00:00:00.
# Game win increased OpTic Gaming's Elo from 1451 to 1466.
# Game loss decreased Golden Guardians's Elo from 1424 to 1409.
# Calculating Elo changes from Clutch Gaming's victory over TSM on 2018-02-18 00:00:00.
# Game win increased Clutch Gaming's Elo from 1519 to 1534.
# Game loss decreased TSM's Elo from 1490 to 1475.
# Calculating Elo changes from Golden Guardians's victory over Team Liquid on 2018-02-18 00:00:00.
# Game win increased Golden Guardians's Elo from 1409 to 1431.
# Game loss decreased Team Liquid's Elo from 1539 to 1517.
# Calculating Elo changes from Echo Fox's victory over Cloud9 on 2018-02-18 00:00:00.
# Game win increased Echo Fox's Elo from 1590 to 1606.
# Game loss decreased Cloud9's Elo from 1598 to 1582.
# Calculating Elo changes from 100 Thieves's victory over Counter Logic Gaming on 2018-02-18 00:00:00.
# Game win increased 100 Thieves's Elo from 1474 to 1489.
# Game loss decreased Counter Logic Gaming's Elo from 1457 to 1442.
# Calculating Elo changes from FlyQuest's victory over OpTic Gaming on 2018-02-18 00:00:00.
# Game win increased FlyQuest's Elo from 1458 to 1474.
# Game loss decreased OpTic Gaming's Elo from 1466 to 1450.
# Calculating Elo changes from 100 Thieves's victory over Cloud9 on 2018-02-24 00:00:00.
# Game win increased 100 Thieves's Elo from 1489 to 1509.
# Game loss decreased Cloud9's Elo from 1582 to 1562.
# Calculating Elo changes from Clutch Gaming's victory over Counter Logic Gaming on 2018-02-24 00:00:00.
# Game win increased Clutch Gaming's Elo from 1534 to 1546.
# Game loss decreased Counter Logic Gaming's Elo from 1442 to 1430.
# Calculating Elo changes from TSM's victory over Echo Fox on 2018-02-24 00:00:00.
# Game win increased TSM's Elo from 1475 to 1497.
# Game loss decreased Echo Fox's Elo from 1606 to 1584.
# Calculating Elo changes from OpTic Gaming's victory over Golden Guardians on 2018-02-24 00:00:00.
# Game win increased OpTic Gaming's Elo from 1450 to 1465.
# Game loss decreased Golden Guardians's Elo from 1431 to 1416.
# Calculating Elo changes from Team Liquid's victory over FlyQuest on 2018-02-24 00:00:00.
# Game win increased Team Liquid's Elo from 1517 to 1531.
# Game loss decreased FlyQuest's Elo from 1474 to 1460.
# Calculating Elo changes from TSM's victory over OpTic Gaming on 2018-02-25 00:00:00.
# Game win increased TSM's Elo from 1497 to 1512.
# Game loss decreased OpTic Gaming's Elo from 1465 to 1450.
# Calculating Elo changes from 100 Thieves's victory over FlyQuest on 2018-02-25 00:00:00.
# Game win increased 100 Thieves's Elo from 1509 to 1523.
# Game loss decreased FlyQuest's Elo from 1460 to 1446.
# Calculating Elo changes from Echo Fox's victory over Team Liquid on 2018-02-25 00:00:00.
# Game win increased Echo Fox's Elo from 1584 to 1598.
# Game loss decreased Team Liquid's Elo from 1531 to 1517.
# Calculating Elo changes from Golden Guardians's victory over Counter Logic Gaming on 2018-02-25 00:00:00.
# Game win increased Golden Guardians's Elo from 1416 to 1433.
# Game loss decreased Counter Logic Gaming's Elo from 1430 to 1413.
# Calculating Elo changes from Cloud9's victory over Clutch Gaming on 2018-02-25 00:00:00.
# Game win increased Cloud9's Elo from 1562 to 1577.
# Game loss decreased Clutch Gaming's Elo from 1546 to 1531.
# Calculating Elo changes from Team Liquid's victory over 100 Thieves on 2018-03-03 00:00:00.
# Game win increased Team Liquid's Elo from 1517 to 1533.
# Game loss decreased 100 Thieves's Elo from 1523 to 1507.
# Calculating Elo changes from TSM's victory over FlyQuest on 2018-03-03 00:00:00.
# Game win increased TSM's Elo from 1512 to 1525.
# Game loss decreased FlyQuest's Elo from 1446 to 1433.
# Calculating Elo changes from Counter Logic Gaming's victory over Cloud9 on 2018-03-03 00:00:00.
# Game win increased Counter Logic Gaming's Elo from 1413 to 1436.
# Game loss decreased Cloud9's Elo from 1577 to 1554.
# Calculating Elo changes from Golden Guardians's victory over Echo Fox on 2018-03-03 00:00:00.
# Game win increased Golden Guardians's Elo from 1433 to 1456.
# Game loss decreased Echo Fox's Elo from 1598 to 1575.
# Calculating Elo changes from Clutch Gaming's victory over OpTic Gaming on 2018-03-03 00:00:00.
# Game win increased Clutch Gaming's Elo from 1531 to 1543.
# Game loss decreased OpTic Gaming's Elo from 1450 to 1438.
# Calculating Elo changes from Counter Logic Gaming's victory over Team Liquid on 2018-03-04 00:00:00.
# Game win increased Counter Logic Gaming's Elo from 1436 to 1456.
# Game loss decreased Team Liquid's Elo from 1533 to 1513.
# Calculating Elo changes from Echo Fox's victory over OpTic Gaming on 2018-03-04 00:00:00.
# Game win increased Echo Fox's Elo from 1575 to 1585.
# Game loss decreased OpTic Gaming's Elo from 1438 to 1428.
# Calculating Elo changes from 100 Thieves's victory over TSM on 2018-03-04 00:00:00.
# Game win increased 100 Thieves's Elo from 1507 to 1524.
# Game loss decreased TSM's Elo from 1525 to 1508.
# Calculating Elo changes from Cloud9's victory over Golden Guardians on 2018-03-04 00:00:00.
# Game win increased Cloud9's Elo from 1554 to 1566.
# Game loss decreased Golden Guardians's Elo from 1456 to 1444.
# Calculating Elo changes from Clutch Gaming's victory over FlyQuest on 2018-03-04 00:00:00.
# Game win increased Clutch Gaming's Elo from 1543 to 1554.
# Game loss decreased FlyQuest's Elo from 1433 to 1422.
# Calculating Elo changes from Clutch Gaming's victory over Echo Fox on 2018-03-10 00:00:00.
# Game win increased Clutch Gaming's Elo from 1554 to 1571.
# Game loss decreased Echo Fox's Elo from 1585 to 1568.
# Calculating Elo changes from Counter Logic Gaming's victory over FlyQuest on 2018-03-10 00:00:00.
# Game win increased Counter Logic Gaming's Elo from 1456 to 1470.
# Game loss decreased FlyQuest's Elo from 1422 to 1408.
# Calculating Elo changes from Cloud9's victory over OpTic Gaming on 2018-03-10 00:00:00.
# Game win increased Cloud9's Elo from 1566 to 1576.
# Game loss decreased OpTic Gaming's Elo from 1428 to 1418.
# Calculating Elo changes from TSM's victory over Team Liquid on 2018-03-10 00:00:00.
# Game win increased TSM's Elo from 1508 to 1524.
# Game loss decreased Team Liquid's Elo from 1513 to 1497.
# Calculating Elo changes from 100 Thieves's victory over Golden Guardians on 2018-03-10 00:00:00.
# Game win increased 100 Thieves's Elo from 1524 to 1536.
# Game loss decreased Golden Guardians's Elo from 1444 to 1432.
# Calculating Elo changes from Counter Logic Gaming's victory over Echo Fox on 2018-03-11 00:00:00.
# Game win increased Counter Logic Gaming's Elo from 1470 to 1490.
# Game loss decreased Echo Fox's Elo from 1568 to 1548.
# Calculating Elo changes from FlyQuest's victory over Golden Guardians on 2018-03-11 00:00:00.
# Game win increased FlyQuest's Elo from 1408 to 1425.
# Game loss decreased Golden Guardians's Elo from 1432 to 1415.
# Calculating Elo changes from Team Liquid's victory over Clutch Gaming on 2018-03-11 00:00:00.
# Game win increased Team Liquid's Elo from 1497 to 1516.
# Game loss decreased Clutch Gaming's Elo from 1571 to 1552.
# Calculating Elo changes from TSM's victory over Cloud9 on 2018-03-11 00:00:00.
# Game win increased TSM's Elo from 1524 to 1542.
# Game loss decreased Cloud9's Elo from 1576 to 1558.
# Calculating Elo changes from 100 Thieves's victory over OpTic Gaming on 2018-03-11 00:00:00.
# Game win increased 100 Thieves's Elo from 1536 to 1547.
# Game loss decreased OpTic Gaming's Elo from 1418 to 1407.
# Calculating Elo changes from 100 Thieves's victory over Clutch Gaming on 2018-03-17 00:00:00.
# Game win increased 100 Thieves's Elo from 1547 to 1563.
# Game loss decreased Clutch Gaming's Elo from 1552 to 1536.
# Calculating Elo changes from Echo Fox's victory over FlyQuest on 2018-03-17 00:00:00.
# Game win increased Echo Fox's Elo from 1548 to 1559.
# Game loss decreased FlyQuest's Elo from 1425 to 1414.
# Calculating Elo changes from Team Liquid's victory over Cloud9 on 2018-03-17 00:00:00.
# Game win increased Team Liquid's Elo from 1516 to 1534.
# Game loss decreased Cloud9's Elo from 1558 to 1540.
# Calculating Elo changes from TSM's victory over Golden Guardians on 2018-03-17 00:00:00.
# Game win increased TSM's Elo from 1542 to 1552.
# Game loss decreased Golden Guardians's Elo from 1415 to 1405.
# Calculating Elo changes from OpTic Gaming's victory over Counter Logic Gaming on 2018-03-17 00:00:00.
# Game win increased OpTic Gaming's Elo from 1407 to 1427.
# Game loss decreased Counter Logic Gaming's Elo from 1490 to 1470.
# Calculating Elo changes from KSV's victory over KING-ZONE DragonX on 2018-01-16 00:00:00.
# Game win increased KSV's Elo from 1600 to 1616.
# Game loss decreased KING-ZONE DragonX's Elo from 1600 to 1584.
# Calculating Elo changes from KSV's victory over KING-ZONE DragonX on 2018-01-16 08:00:00.
# Game win increased KSV's Elo from 1616 to 1631.
# Game loss decreased KING-ZONE DragonX's Elo from 1584 to 1569.
# Calculating Elo changes from KONGDOO MONSTER's victory over MVP on 2018-01-16 00:00:00.
# Game win increased KONGDOO MONSTER's Elo from 1600 to 1616.
# Game loss decreased MVP's Elo from 1600 to 1584.
# Calculating Elo changes from KONGDOO MONSTER's victory over MVP on 2018-01-16 08:00:00.
# Game win increased KONGDOO MONSTER's Elo from 1616 to 1631.
# Game loss decreased MVP's Elo from 1584 to 1569.
# Calculating Elo changes from Afreeca Freecs's victory over kt Rolster on 2018-01-17 00:00:00.
# Game win increased Afreeca Freecs's Elo from 1600 to 1616.
# Game loss decreased kt Rolster's Elo from 1600 to 1584.
# Calculating Elo changes from kt Rolster's victory over Afreeca Freecs on 2018-01-17 08:00:00.
# Game win increased kt Rolster's Elo from 1584 to 1601.
# Game loss decreased Afreeca Freecs's Elo from 1616 to 1599.
# Calculating Elo changes from Afreeca Freecs's victory over kt Rolster on 2018-01-17 16:00:00.
# Game win increased Afreeca Freecs's Elo from 1599 to 1615.
# Game loss decreased kt Rolster's Elo from 1601 to 1585.
# Calculating Elo changes from SK telecom T1's victory over ROX Tigers on 2018-01-17 00:00:00.
# Game win increased SK telecom T1's Elo from 1600 to 1616.
# Game loss decreased ROX Tigers's Elo from 1600 to 1584.
# Calculating Elo changes from ROX Tigers's victory over SK telecom T1 on 2018-01-17 08:00:00.
# Game win increased ROX Tigers's Elo from 1584 to 1601.
# Game loss decreased SK telecom T1's Elo from 1616 to 1599.
# Calculating Elo changes from SK telecom T1's victory over ROX Tigers on 2018-01-17 16:00:00.
# Game win increased SK telecom T1's Elo from 1599 to 1615.
# Game loss decreased ROX Tigers's Elo from 1601 to 1585.
# Calculating Elo changes from bbq OLIVERS's victory over KONGDOO MONSTER on 2018-01-18 00:00:00.
# Game win increased bbq OLIVERS's Elo from 1600 to 1617.
# Game loss decreased KONGDOO MONSTER's Elo from 1631 to 1614.
# Calculating Elo changes from KONGDOO MONSTER's victory over bbq OLIVERS on 2018-01-18 08:00:00.
# Game win increased KONGDOO MONSTER's Elo from 1614 to 1630.
# Game loss decreased bbq OLIVERS's Elo from 1617 to 1601.
# Calculating Elo changes from bbq OLIVERS's victory over KONGDOO MONSTER on 2018-01-18 16:00:00.
# Game win increased bbq OLIVERS's Elo from 1601 to 1618.
# Game loss decreased KONGDOO MONSTER's Elo from 1630 to 1613.
# Calculating Elo changes from KSV's victory over Jin Air GreenWings on 2018-01-18 00:00:00.
# Game win increased KSV's Elo from 1631 to 1646.
# Game loss decreased Jin Air GreenWings's Elo from 1600 to 1585.
# Calculating Elo changes from KSV's victory over Jin Air GreenWings on 2018-01-18 08:00:00.
# Game win increased KSV's Elo from 1646 to 1659.
# Game loss decreased Jin Air GreenWings's Elo from 1585 to 1572.
# Calculating Elo changes from kt Rolster's victory over MVP on 2018-01-20 00:00:00.
# Game win increased kt Rolster's Elo from 1585 to 1600.
# Game loss decreased MVP's Elo from 1569 to 1554.
# Calculating Elo changes from kt Rolster's victory over MVP on 2018-01-20 08:00:00.
# Game win increased kt Rolster's Elo from 1600 to 1614.
# Game loss decreased MVP's Elo from 1554 to 1540.
# Calculating Elo changes from Jin Air GreenWings's victory over SK telecom T1 on 2018-01-20 00:00:00.
# Game win increased Jin Air GreenWings's Elo from 1572 to 1590.
# Game loss decreased SK telecom T1's Elo from 1615 to 1597.
# Calculating Elo changes from SK telecom T1's victory over Jin Air GreenWings on 2018-01-20 08:00:00.
# Game win increased SK telecom T1's Elo from 1597 to 1613.
# Game loss decreased Jin Air GreenWings's Elo from 1590 to 1574.
# Calculating Elo changes from Jin Air GreenWings's victory over SK telecom T1 on 2018-01-20 16:00:00.
# Game win increased Jin Air GreenWings's Elo from 1574 to 1592.
# Game loss decreased SK telecom T1's Elo from 1613 to 1595.
# Calculating Elo changes from KING-ZONE DragonX's victory over Afreeca Freecs on 2018-01-23 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1569 to 1587.
# Game loss decreased Afreeca Freecs's Elo from 1615 to 1597.
# Calculating Elo changes from KING-ZONE DragonX's victory over Afreeca Freecs on 2018-01-23 08:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1587 to 1603.
# Game loss decreased Afreeca Freecs's Elo from 1597 to 1581.
# Calculating Elo changes from ROX Tigers's victory over bbq OLIVERS on 2018-01-23 00:00:00.
# Game win increased ROX Tigers's Elo from 1585 to 1603.
# Game loss decreased bbq OLIVERS's Elo from 1618 to 1600.
# Calculating Elo changes from bbq OLIVERS's victory over ROX Tigers on 2018-01-23 08:00:00.
# Game win increased bbq OLIVERS's Elo from 1600 to 1616.
# Game loss decreased ROX Tigers's Elo from 1603 to 1587.
# Calculating Elo changes from ROX Tigers's victory over bbq OLIVERS on 2018-01-23 16:00:00.
# Game win increased ROX Tigers's Elo from 1587 to 1604.
# Game loss decreased bbq OLIVERS's Elo from 1616 to 1599.
# Calculating Elo changes from Jin Air GreenWings's victory over MVP on 2018-01-24 00:00:00.
# Game win increased Jin Air GreenWings's Elo from 1592 to 1606.
# Game loss decreased MVP's Elo from 1540 to 1526.
# Calculating Elo changes from Jin Air GreenWings's victory over MVP on 2018-01-24 08:00:00.
# Game win increased Jin Air GreenWings's Elo from 1606 to 1618.
# Game loss decreased MVP's Elo from 1526 to 1514.
# Calculating Elo changes from kt Rolster's victory over SK telecom T1 on 2018-01-24 00:00:00.
# Game win increased kt Rolster's Elo from 1614 to 1629.
# Game loss decreased SK telecom T1's Elo from 1595 to 1580.
# Calculating Elo changes from SK telecom T1's victory over kt Rolster on 2018-01-24 08:00:00.
# Game win increased SK telecom T1's Elo from 1580 to 1598.
# Game loss decreased kt Rolster's Elo from 1629 to 1611.
# Calculating Elo changes from kt Rolster's victory over SK telecom T1 on 2018-01-24 16:00:00.
# Game win increased kt Rolster's Elo from 1611 to 1626.
# Game loss decreased SK telecom T1's Elo from 1598 to 1583.
# Calculating Elo changes from ROX Tigers's victory over KONGDOO MONSTER on 2018-01-25 00:00:00.
# Game win increased ROX Tigers's Elo from 1604 to 1620.
# Game loss decreased KONGDOO MONSTER's Elo from 1613 to 1597.
# Calculating Elo changes from KONGDOO MONSTER's victory over ROX Tigers on 2018-01-25 08:00:00.
# Game win increased KONGDOO MONSTER's Elo from 1597 to 1614.
# Game loss decreased ROX Tigers's Elo from 1620 to 1603.
# Calculating Elo changes from ROX Tigers's victory over KONGDOO MONSTER on 2018-01-25 16:00:00.
# Game win increased ROX Tigers's Elo from 1603 to 1620.
# Game loss decreased KONGDOO MONSTER's Elo from 1614 to 1597.
# Calculating Elo changes from KSV's victory over Afreeca Freecs on 2018-01-25 00:00:00.
# Game win increased KSV's Elo from 1659 to 1671.
# Game loss decreased Afreeca Freecs's Elo from 1581 to 1569.
# Calculating Elo changes from Afreeca Freecs's victory over KSV on 2018-01-25 08:00:00.
# Game win increased Afreeca Freecs's Elo from 1569 to 1590.
# Game loss decreased KSV's Elo from 1671 to 1650.
# Calculating Elo changes from KSV's victory over Afreeca Freecs on 2018-01-25 16:00:00.
# Game win increased KSV's Elo from 1650 to 1663.
# Game loss decreased Afreeca Freecs's Elo from 1590 to 1577.
# Calculating Elo changes from KING-ZONE DragonX's victory over SK telecom T1 on 2018-01-26 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1603 to 1618.
# Game loss decreased SK telecom T1's Elo from 1583 to 1568.
# Calculating Elo changes from KING-ZONE DragonX's victory over SK telecom T1 on 2018-01-26 08:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1618 to 1632.
# Game loss decreased SK telecom T1's Elo from 1568 to 1554.
# Calculating Elo changes from kt Rolster's victory over bbq OLIVERS on 2018-01-26 00:00:00.
# Game win increased kt Rolster's Elo from 1626 to 1641.
# Game loss decreased bbq OLIVERS's Elo from 1599 to 1584.
# Calculating Elo changes from bbq OLIVERS's victory over kt Rolster on 2018-01-26 08:00:00.
# Game win increased bbq OLIVERS's Elo from 1584 to 1603.
# Game loss decreased kt Rolster's Elo from 1641 to 1622.
# Calculating Elo changes from kt Rolster's victory over bbq OLIVERS on 2018-01-26 16:00:00.
# Game win increased kt Rolster's Elo from 1622 to 1637.
# Game loss decreased bbq OLIVERS's Elo from 1603 to 1588.
# Calculating Elo changes from KONGDOO MONSTER's victory over KSV on 2018-01-27 00:00:00.
# Game win increased KONGDOO MONSTER's Elo from 1597 to 1616.
# Game loss decreased KSV's Elo from 1663 to 1644.
# Calculating Elo changes from KONGDOO MONSTER's victory over KSV on 2018-01-27 08:00:00.
# Game win increased KONGDOO MONSTER's Elo from 1616 to 1633.
# Game loss decreased KSV's Elo from 1644 to 1627.
# Calculating Elo changes from Afreeca Freecs's victory over ROX Tigers on 2018-01-27 00:00:00.
# Game win increased Afreeca Freecs's Elo from 1577 to 1595.
# Game loss decreased ROX Tigers's Elo from 1620 to 1602.
# Calculating Elo changes from Afreeca Freecs's victory over ROX Tigers on 2018-01-27 08:00:00.
# Game win increased Afreeca Freecs's Elo from 1595 to 1611.
# Game loss decreased ROX Tigers's Elo from 1602 to 1586.
# Calculating Elo changes from bbq OLIVERS's victory over Jin Air GreenWings on 2018-01-28 00:00:00.
# Game win increased bbq OLIVERS's Elo from 1588 to 1605.
# Game loss decreased Jin Air GreenWings's Elo from 1618 to 1601.
# Calculating Elo changes from bbq OLIVERS's victory over Jin Air GreenWings on 2018-01-28 08:00:00.
# Game win increased bbq OLIVERS's Elo from 1605 to 1621.
# Game loss decreased Jin Air GreenWings's Elo from 1601 to 1585.
# Calculating Elo changes from KING-ZONE DragonX's victory over MVP on 2018-01-28 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1632 to 1643.
# Game loss decreased MVP's Elo from 1514 to 1503.
# Calculating Elo changes from KING-ZONE DragonX's victory over MVP on 2018-01-28 08:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1643 to 1653.
# Game loss decreased MVP's Elo from 1503 to 1493.
# Calculating Elo changes from KSV's victory over MVP on 2018-01-30 00:00:00.
# Game win increased KSV's Elo from 1627 to 1637.
# Game loss decreased MVP's Elo from 1493 to 1483.
# Calculating Elo changes from KSV's victory over MVP on 2018-01-30 08:00:00.
# Game win increased KSV's Elo from 1637 to 1646.
# Game loss decreased MVP's Elo from 1483 to 1474.
# Calculating Elo changes from Jin Air GreenWings's victory over KONGDOO MONSTER on 2018-01-30 00:00:00.
# Game win increased Jin Air GreenWings's Elo from 1585 to 1603.
# Game loss decreased KONGDOO MONSTER's Elo from 1633 to 1615.
# Calculating Elo changes from Jin Air GreenWings's victory over KONGDOO MONSTER on 2018-01-30 08:00:00.
# Game win increased Jin Air GreenWings's Elo from 1603 to 1620.
# Game loss decreased KONGDOO MONSTER's Elo from 1615 to 1598.
# Calculating Elo changes from KING-ZONE DragonX's victory over ROX Tigers on 2018-01-31 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1653 to 1666.
# Game loss decreased ROX Tigers's Elo from 1586 to 1573.
# Calculating Elo changes from KING-ZONE DragonX's victory over ROX Tigers on 2018-01-31 08:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1666 to 1678.
# Game loss decreased ROX Tigers's Elo from 1573 to 1561.
# Calculating Elo changes from Afreeca Freecs's victory over bbq OLIVERS on 2018-01-31 00:00:00.
# Game win increased Afreeca Freecs's Elo from 1611 to 1627.
# Game loss decreased bbq OLIVERS's Elo from 1621 to 1605.
# Calculating Elo changes from Afreeca Freecs's victory over bbq OLIVERS on 2018-01-31 08:00:00.
# Game win increased Afreeca Freecs's Elo from 1627 to 1642.
# Game loss decreased bbq OLIVERS's Elo from 1605 to 1590.
# Calculating Elo changes from kt Rolster's victory over Jin Air GreenWings on 2018-02-01 00:00:00.
# Game win increased kt Rolster's Elo from 1637 to 1652.
# Game loss decreased Jin Air GreenWings's Elo from 1620 to 1605.
# Calculating Elo changes from kt Rolster's victory over Jin Air GreenWings on 2018-02-01 08:00:00.
# Game win increased kt Rolster's Elo from 1652 to 1666.
# Game loss decreased Jin Air GreenWings's Elo from 1605 to 1591.
# Calculating Elo changes from MVP's victory over SK telecom T1 on 2018-02-01 00:00:00.
# Game win increased MVP's Elo from 1474 to 1494.
# Game loss decreased SK telecom T1's Elo from 1554 to 1534.
# Calculating Elo changes from SK telecom T1's victory over MVP on 2018-02-01 08:00:00.
# Game win increased SK telecom T1's Elo from 1534 to 1548.
# Game loss decreased MVP's Elo from 1494 to 1480.
# ...
# Calculating Elo changes from SK telecom T1's victory over ROX Tigers on 2018-02-24 00:00:00.
# Game win increased SK telecom T1's Elo from 1585 to 1603.
# Game loss decreased ROX Tigers's Elo from 1624 to 1606.
# Calculating Elo changes from SK telecom T1's victory over ROX Tigers on 2018-02-24 08:00:00.
# Game win increased SK telecom T1's Elo from 1603 to 1619.
# Game loss decreased ROX Tigers's Elo from 1606 to 1590.
# Calculating Elo changes from KING-ZONE DragonX's victory over Afreeca Freecs on 2018-02-24 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1706 to 1720.
# Game loss decreased Afreeca Freecs's Elo from 1660 to 1646.
# Calculating Elo changes from Afreeca Freecs's victory over KING-ZONE DragonX on 2018-02-24 08:00:00.
# Game win increased Afreeca Freecs's Elo from 1646 to 1665.
# Game loss decreased KING-ZONE DragonX's Elo from 1720 to 1701.
# Calculating Elo changes from KING-ZONE DragonX's victory over Afreeca Freecs on 2018-02-24 16:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1701 to 1715.
# Game loss decreased Afreeca Freecs's Elo from 1665 to 1651.
# Calculating Elo changes from kt Rolster's victory over Jin Air GreenWings on 2018-02-25 00:00:00.
# Game win increased kt Rolster's Elo from 1684 to 1696.
# Game loss decreased Jin Air GreenWings's Elo from 1600 to 1588.
# Calculating Elo changes from Jin Air GreenWings's victory over kt Rolster on 2018-02-25 08:00:00.
# Game win increased Jin Air GreenWings's Elo from 1588 to 1609.
# Game loss decreased kt Rolster's Elo from 1696 to 1675.
# Calculating Elo changes from kt Rolster's victory over Jin Air GreenWings on 2018-02-25 16:00:00.
# Game win increased kt Rolster's Elo from 1675 to 1688.
# Game loss decreased Jin Air GreenWings's Elo from 1609 to 1596.
# Calculating Elo changes from MVP's victory over bbq OLIVERS on 2018-02-25 00:00:00.
# Game win increased MVP's Elo from 1497 to 1516.
# Game loss decreased bbq OLIVERS's Elo from 1562 to 1543.
# Calculating Elo changes from MVP's victory over bbq OLIVERS on 2018-02-25 08:00:00.
# Game win increased MVP's Elo from 1516 to 1533.
# Game loss decreased bbq OLIVERS's Elo from 1543 to 1526.
# Calculating Elo changes from Afreeca Freecs's victory over KSV on 2018-02-27 00:00:00.
# Game win increased Afreeca Freecs's Elo from 1651 to 1663.
# Game loss decreased KSV's Elo from 1566 to 1554.
# Calculating Elo changes from Afreeca Freecs's victory over KSV on 2018-02-27 08:00:00.
# Game win increased Afreeca Freecs's Elo from 1663 to 1674.
# Game loss decreased KSV's Elo from 1554 to 1543.
# Calculating Elo changes from ROX Tigers's victory over kt Rolster on 2018-02-27 00:00:00.
# Game win increased ROX Tigers's Elo from 1590 to 1610.
# Game loss decreased kt Rolster's Elo from 1688 to 1668.
# Calculating Elo changes from ROX Tigers's victory over kt Rolster on 2018-02-27 08:00:00.
# Game win increased ROX Tigers's Elo from 1610 to 1629.
# Game loss decreased kt Rolster's Elo from 1668 to 1649.
# Calculating Elo changes from bbq OLIVERS's victory over Jin Air GreenWings on 2018-02-28 00:00:00.
# Game win increased bbq OLIVERS's Elo from 1526 to 1545.
# Game loss decreased Jin Air GreenWings's Elo from 1596 to 1577.
# Calculating Elo changes from bbq OLIVERS's victory over Jin Air GreenWings on 2018-02-28 08:00:00.
# Game win increased bbq OLIVERS's Elo from 1545 to 1562.
# Game loss decreased Jin Air GreenWings's Elo from 1577 to 1560.
# Calculating Elo changes from KING-ZONE DragonX's victory over MVP on 2018-02-28 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1715 to 1723.
# Game loss decreased MVP's Elo from 1533 to 1525.
# Calculating Elo changes from KING-ZONE DragonX's victory over MVP on 2018-02-28 08:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1723 to 1731.
# Game loss decreased MVP's Elo from 1525 to 1517.
# Calculating Elo changes from Afreeca Freecs's victory over SK telecom T1 on 2018-03-01 00:00:00.
# Game win increased Afreeca Freecs's Elo from 1674 to 1687.
# Game loss decreased SK telecom T1's Elo from 1619 to 1606.
# Calculating Elo changes from SK telecom T1's victory over Afreeca Freecs on 2018-03-01 08:00:00.
# Game win increased SK telecom T1's Elo from 1606 to 1626.
# Game loss decreased Afreeca Freecs's Elo from 1687 to 1667.
# Calculating Elo changes from Afreeca Freecs's victory over SK telecom T1 on 2018-03-01 16:00:00.
# Game win increased Afreeca Freecs's Elo from 1667 to 1681.
# Game loss decreased SK telecom T1's Elo from 1626 to 1612.
# Calculating Elo changes from kt Rolster's victory over KONGDOO MONSTER on 2018-03-01 00:00:00.
# Game win increased kt Rolster's Elo from 1649 to 1659.
# Game loss decreased KONGDOO MONSTER's Elo from 1516 to 1506.
# Calculating Elo changes from kt Rolster's victory over KONGDOO MONSTER on 2018-03-01 08:00:00.
# Game win increased kt Rolster's Elo from 1659 to 1668.
# Game loss decreased KONGDOO MONSTER's Elo from 1506 to 1497.
# Calculating Elo changes from KING-ZONE DragonX's victory over KONGDOO MONSTER on 2018-03-03 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1731 to 1738.
# Game loss decreased KONGDOO MONSTER's Elo from 1497 to 1490.
# Calculating Elo changes from KING-ZONE DragonX's victory over KONGDOO MONSTER on 2018-03-03 08:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1738 to 1744.
# Game loss decreased KONGDOO MONSTER's Elo from 1490 to 1484.
# Calculating Elo changes from ROX Tigers's victory over bbq OLIVERS on 2018-03-03 00:00:00.
# Game win increased ROX Tigers's Elo from 1629 to 1642.
# Game loss decreased bbq OLIVERS's Elo from 1562 to 1549.
# Calculating Elo changes from ROX Tigers's victory over bbq OLIVERS on 2018-03-03 08:00:00.
# Game win increased ROX Tigers's Elo from 1642 to 1654.
# Game loss decreased bbq OLIVERS's Elo from 1549 to 1537.
# Calculating Elo changes from SK telecom T1's victory over Jin Air GreenWings on 2018-03-04 00:00:00.
# Game win increased SK telecom T1's Elo from 1612 to 1626.
# Game loss decreased Jin Air GreenWings's Elo from 1560 to 1546.
# Calculating Elo changes from Jin Air GreenWings's victory over SK telecom T1 on 2018-03-04 08:00:00.
# Game win increased Jin Air GreenWings's Elo from 1546 to 1566.
# Game loss decreased SK telecom T1's Elo from 1626 to 1606.
# Calculating Elo changes from SK telecom T1's victory over Jin Air GreenWings on 2018-03-04 16:00:00.
# Game win increased SK telecom T1's Elo from 1606 to 1620.
# Game loss decreased Jin Air GreenWings's Elo from 1566 to 1552.
# Calculating Elo changes from MVP's victory over KSV on 2018-03-04 00:00:00.
# Game win increased MVP's Elo from 1517 to 1534.
# Game loss decreased KSV's Elo from 1543 to 1526.
# Calculating Elo changes from KSV's victory over MVP on 2018-03-04 08:00:00.
# Game win increased KSV's Elo from 1526 to 1542.
# Game loss decreased MVP's Elo from 1534 to 1518.
# Calculating Elo changes from MVP's victory over KSV on 2018-03-04 16:00:00.
# Game win increased MVP's Elo from 1518 to 1535.
# Game loss decreased KSV's Elo from 1542 to 1525.
# Calculating Elo changes from KING-ZONE DragonX's victory over SK telecom T1 on 2018-03-06 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1744 to 1755.
# Game loss decreased SK telecom T1's Elo from 1620 to 1609.
# Calculating Elo changes from KING-ZONE DragonX's victory over SK telecom T1 on 2018-03-06 08:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1755 to 1765.
# Game loss decreased SK telecom T1's Elo from 1609 to 1599.
# Calculating Elo changes from MVP's victory over ROX Tigers on 2018-03-06 00:00:00.
# Game win increased MVP's Elo from 1535 to 1556.
# Game loss decreased ROX Tigers's Elo from 1654 to 1633.
# Calculating Elo changes from MVP's victory over ROX Tigers on 2018-03-06 08:00:00.
# Game win increased MVP's Elo from 1556 to 1575.
# Game loss decreased ROX Tigers's Elo from 1633 to 1614.
# Calculating Elo changes from Jin Air GreenWings's victory over KONGDOO MONSTER on 2018-03-07 00:00:00.
# Game win increased Jin Air GreenWings's Elo from 1552 to 1565.
# Game loss decreased KONGDOO MONSTER's Elo from 1484 to 1471.
# Calculating Elo changes from Jin Air GreenWings's victory over KONGDOO MONSTER on 2018-03-07 08:00:00.
# Game win increased Jin Air GreenWings's Elo from 1565 to 1577.
# Game loss decreased KONGDOO MONSTER's Elo from 1471 to 1459.
# Calculating Elo changes from KSV's victory over bbq OLIVERS on 2018-03-07 00:00:00.
# Game win increased KSV's Elo from 1525 to 1542.
# Game loss decreased bbq OLIVERS's Elo from 1537 to 1520.
# Calculating Elo changes from KSV's victory over bbq OLIVERS on 2018-03-07 08:00:00.
# Game win increased KSV's Elo from 1542 to 1557.
# Game loss decreased bbq OLIVERS's Elo from 1520 to 1505.
# Calculating Elo changes from kt Rolster's victory over SK telecom T1 on 2018-03-08 00:00:00.
# Game win increased kt Rolster's Elo from 1668 to 1681.
# Game loss decreased SK telecom T1's Elo from 1599 to 1586.
# Calculating Elo changes from kt Rolster's victory over SK telecom T1 on 2018-03-08 08:00:00.
# Game win increased kt Rolster's Elo from 1681 to 1693.
# Game loss decreased SK telecom T1's Elo from 1586 to 1574.
# Calculating Elo changes from Afreeca Freecs's victory over ROX Tigers on 2018-03-08 00:00:00.
# Game win increased Afreeca Freecs's Elo from 1681 to 1694.
# Game loss decreased ROX Tigers's Elo from 1614 to 1601.
# Calculating Elo changes from Afreeca Freecs's victory over ROX Tigers on 2018-03-08 08:00:00.
# Game win increased Afreeca Freecs's Elo from 1694 to 1706.
# Game loss decreased ROX Tigers's Elo from 1601 to 1589.
# Calculating Elo changes from Jin Air GreenWings's victory over MVP on 2018-03-10 00:00:00.
# Game win increased Jin Air GreenWings's Elo from 1577 to 1593.
# Game loss decreased MVP's Elo from 1575 to 1559.
# Calculating Elo changes from MVP's victory over Jin Air GreenWings on 2018-03-10 08:00:00.
# Game win increased MVP's Elo from 1559 to 1577.
# Game loss decreased Jin Air GreenWings's Elo from 1593 to 1575.
# Calculating Elo changes from Jin Air GreenWings's victory over MVP on 2018-03-10 16:00:00.
# Game win increased Jin Air GreenWings's Elo from 1575 to 1591.
# Game loss decreased MVP's Elo from 1577 to 1561.
# Calculating Elo changes from KSV's victory over kt Rolster on 2018-03-10 00:00:00.
# Game win increased KSV's Elo from 1557 to 1579.
# Game loss decreased kt Rolster's Elo from 1693 to 1671.
# Calculating Elo changes from kt Rolster's victory over KSV on 2018-03-10 08:00:00.
# Game win increased kt Rolster's Elo from 1671 to 1683.
# Game loss decreased KSV's Elo from 1579 to 1567.
# Calculating Elo changes from KSV's victory over kt Rolster on 2018-03-10 16:00:00.
# Game win increased KSV's Elo from 1567 to 1588.
# Game loss decreased kt Rolster's Elo from 1683 to 1662.
# Calculating Elo changes from Afreeca Freecs's victory over KONGDOO MONSTER on 2018-03-11 00:00:00.
# Game win increased Afreeca Freecs's Elo from 1706 to 1712.
# Game loss decreased KONGDOO MONSTER's Elo from 1459 to 1453.
# Calculating Elo changes from Afreeca Freecs's victory over KONGDOO MONSTER on 2018-03-11 08:00:00.
# Game win increased Afreeca Freecs's Elo from 1712 to 1718.
# Game loss decreased KONGDOO MONSTER's Elo from 1453 to 1447.
# Calculating Elo changes from KING-ZONE DragonX's victory over bbq OLIVERS on 2018-03-11 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1765 to 1771.
# Game loss decreased bbq OLIVERS's Elo from 1505 to 1499.
# Calculating Elo changes from KING-ZONE DragonX's victory over bbq OLIVERS on 2018-03-11 08:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1771 to 1777.
# Game loss decreased bbq OLIVERS's Elo from 1499 to 1493.
# Calculating Elo changes from KING-ZONE DragonX's victory over ROX Tigers on 2018-03-13 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1777 to 1785.
# Game loss decreased ROX Tigers's Elo from 1589 to 1581.
# Calculating Elo changes from ROX Tigers's victory over KING-ZONE DragonX on 2018-03-13 08:00:00.
# Game win increased ROX Tigers's Elo from 1581 to 1605.
# Game loss decreased KING-ZONE DragonX's Elo from 1785 to 1761.
# Calculating Elo changes from KING-ZONE DragonX's victory over ROX Tigers on 2018-03-13 16:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1761 to 1770.
# Game loss decreased ROX Tigers's Elo from 1605 to 1596.
# Calculating Elo changes from KSV's victory over Jin Air GreenWings on 2018-03-13 00:00:00.
# Game win increased KSV's Elo from 1588 to 1604.
# Game loss decreased Jin Air GreenWings's Elo from 1591 to 1575.
# Calculating Elo changes from Jin Air GreenWings's victory over KSV on 2018-03-13 08:00:00.
# Game win increased Jin Air GreenWings's Elo from 1575 to 1592.
# Game loss decreased KSV's Elo from 1604 to 1587.
# Calculating Elo changes from KSV's victory over Jin Air GreenWings on 2018-03-13 16:00:00.
# Game win increased KSV's Elo from 1587 to 1603.
# Game loss decreased Jin Air GreenWings's Elo from 1592 to 1576.
# Calculating Elo changes from MVP's victory over KONGDOO MONSTER on 2018-03-14 00:00:00.
# Game win increased MVP's Elo from 1561 to 1572.
# Game loss decreased KONGDOO MONSTER's Elo from 1447 to 1436.
# Calculating Elo changes from KONGDOO MONSTER's victory over MVP on 2018-03-14 08:00:00.
# Game win increased KONGDOO MONSTER's Elo from 1436 to 1458.
# Game loss decreased MVP's Elo from 1572 to 1550.
# Calculating Elo changes from MVP's victory over KONGDOO MONSTER on 2018-03-14 16:00:00.
# Game win increased MVP's Elo from 1550 to 1562.
# Game loss decreased KONGDOO MONSTER's Elo from 1458 to 1446.
# Calculating Elo changes from bbq OLIVERS's victory over SK telecom T1 on 2018-03-14 00:00:00.
# Game win increased bbq OLIVERS's Elo from 1493 to 1513.
# Game loss decreased SK telecom T1's Elo from 1574 to 1554.
# Calculating Elo changes from SK telecom T1's victory over bbq OLIVERS on 2018-03-14 08:00:00.
# Game win increased SK telecom T1's Elo from 1554 to 1568.
# Game loss decreased bbq OLIVERS's Elo from 1513 to 1499.
# Calculating Elo changes from bbq OLIVERS's victory over SK telecom T1 on 2018-03-14 16:00:00.
# Game win increased bbq OLIVERS's Elo from 1499 to 1518.
# Game loss decreased SK telecom T1's Elo from 1568 to 1549.
# Calculating Elo changes from Afreeca Freecs's victory over Jin Air GreenWings on 2018-03-15 00:00:00.
# Game win increased Afreeca Freecs's Elo from 1718 to 1728.
# Game loss decreased Jin Air GreenWings's Elo from 1576 to 1566.
# Calculating Elo changes from Jin Air GreenWings's victory over Afreeca Freecs on 2018-03-15 08:00:00.
# Game win increased Jin Air GreenWings's Elo from 1566 to 1589.
# Game loss decreased Afreeca Freecs's Elo from 1728 to 1705.
# Calculating Elo changes from Afreeca Freecs's victory over Jin Air GreenWings on 2018-03-15 16:00:00.
# Game win increased Afreeca Freecs's Elo from 1705 to 1716.
# Game loss decreased Jin Air GreenWings's Elo from 1589 to 1578.
# Calculating Elo changes from KING-ZONE DragonX's victory over kt Rolster on 2018-03-15 00:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1770 to 1781.
# Game loss decreased kt Rolster's Elo from 1662 to 1651.
# Calculating Elo changes from KING-ZONE DragonX's victory over kt Rolster on 2018-03-15 08:00:00.
# Game win increased KING-ZONE DragonX's Elo from 1781 to 1791.
# Game loss decreased kt Rolster's Elo from 1651 to 1641.
# Calculating Elo changes from Afreeca Freecs's victory over MVP on 2018-03-17 00:00:00.
# Game win increased Afreeca Freecs's Elo from 1716 to 1725.
# Game loss decreased MVP's Elo from 1562 to 1553.
# Calculating Elo changes from Afreeca Freecs's victory over MVP on 2018-03-17 08:00:00.
# Game win increased Afreeca Freecs's Elo from 1725 to 1734.
# Game loss decreased MVP's Elo from 1553 to 1544.
# Calculating Elo changes from kt Rolster's victory over bbq OLIVERS on 2018-03-17 00:00:00.
# Game win increased kt Rolster's Elo from 1641 to 1652.
# Game loss decreased bbq OLIVERS's Elo from 1518 to 1507.
# Calculating Elo changes from bbq OLIVERS's victory over kt Rolster on 2018-03-17 08:00:00.
# Game win increased bbq OLIVERS's Elo from 1507 to 1529.
# Game loss decreased kt Rolster's Elo from 1652 to 1630.
# Calculating Elo changes from kt Rolster's victory over bbq OLIVERS on 2018-03-17 16:00:00.
# Game win increased kt Rolster's Elo from 1630 to 1641.
# Game loss decreased bbq OLIVERS's Elo from 1529 to 1518.

# %%
# Current ratings
## EU
print("EU Elo-ratings:")
for team in EU.teams:
    print("{}:\t{}".format(team.name, team.rating))
    
## NA
print("\nNA Elo-ratings:")
for team in NA.teams:
    print("{}:\t{}".format(team.name, team.rating))
    
## KR
print("\nKR Elo-ratings:")
for team in KR.teams:
    print("{}:\t{}".format(team.name, team.rating))
# Out:
# EU Elo-ratings:
# Fnatic:	1625
# G2 Esports:	1559
# Splyce:	1537
# Team Vitality:	1506
# H2K:	1504
# Misfits Gaming:	1466
# ROCCAT:	1476
# Giants:	1437
# FC Schalke 04:	1451
# Unicorns of Love:	1439
#
# NA Elo-ratings:
# Echo Fox:	1559
# Cloud9:	1540
# 100 Thieves:	1563
# TSM:	1552
# Clutch Gaming:	1536
# Team Liquid:	1534
# Counter Logic Gaming:	1470
# FlyQuest:	1414
# OpTic Gaming:	1427
# Golden Guardians:	1405
#
# KR Elo-ratings:
# KING-ZONE DragonX:	1791
# Afreeca Freecs:	1734
# kt Rolster:	1641
# KSV:	1603
# ROX Tigers:	1596
# MVP:	1544
# Jin Air GreenWings:	1578
# SK telecom T1:	1549
# bbq OLIVERS:	1518
# KONGDOO MONSTER:	1446

# %%
color_by = { FNC: '#FFA300',
             G2:  '#808080',
             SPY: '#EEBB00',
             VIT: '#FFD700',
             H2K: '#1464F4',
             MSF: '#CD0000',
             ROC: '#1E90FF',
             GIA: '#5190ED',
             S04: '#3A5FCD',
             UOL: '#FF007F',
             FOX: '#E47833',
             C9: '#63D1F4',
             T100: '#FF2400',
             TSM: '#202020',
             CG: '#EE3B3B',
             TL: '#808080',
             CLG: '#37FDFC',
             FLY: '#329555',
             OPT: '#83F52C',
             GGS: '#FFE303',
             KZ: '#3A5FCD',
             AFS: '#0BB5FF',
             KT: '#FF0000',
             KSV: '#FCD116',
             ROX: '#FF8C00',
             MVP: '#0EBFE9',
             JAG: '#ADFF2F',
             SKT: '#FC1501',
             BBQ: '#686868',
             KDM: '#108070'
           }

def plot_ratings(regions, highlight_teams=None):
    
    if highlight_teams == []:
        highlight_teams = None
    
    fig = plt.figure(facecolor='w')
    fig.set_size_inches(12.5, 8.5)
    ax = fig.add_subplot(111, facecolor='#F5F5F5', axisbelow=True)

    for region in regions:
        for team in region.teams:
            if highlight_teams != None:
                if team in highlight_teams:
                    ax.plot(np.array(team.game_dates), np.array(team.rating_history),
                           c=color_by[team], alpha=1, lw=1, label=team.name)
                else:
                    ax.plot(np.array(team.game_dates), np.array(team.rating_history),
                           c='#BEBEBE', alpha=0.5, lw=.75)
            else:
                ax.plot(np.array(team.game_dates), np.array(team.rating_history),
                           c=color_by[team], alpha=1, lw=1, label=team.name)

    ax.set_xlabel('Date')
    ax.set_ylabel('Elo-rating')
#     ax.set_ylim(1400, 1700)
    ax.yaxis.set_tick_params(length=0)
    ax.xaxis.set_tick_params(length=0)
    ax.grid(b=True, which='major', c='w', lw=2, ls='-')
#     legend = ax.legend(handles=[S_patch, I_patch, R_patch])
#     legend.get_frame().set_alpha(0.5)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    for spine in ('top', 'right', 'bottom', 'left'):
        ax.spines[spine].set_visible(False)
    plt.xticks(rotation=90)
    plt.show()

# %%
plot_ratings([KR, EU, NA])

# %%
plot_ratings([KR, EU, NA], [FNC, FOX])
